# %% [markdown]
# 原文参照：https://mmengine.readthedocs.io/zh-cn/latest/examples/train_a_gan.html

# %%
# !pip install -U openmim
# !mim install mmengine
# Out:
# Collecting openmim
#   Downloading openmim-0.3.9-py2.py3-none-any.whl.metadata (16 kB)
# Requirement already satisfied: Click in /usr/local/lib/python3.11/dist-packages (from openmim) (8.1.8)
# Requirement already satisfied: colorama in /usr/local/lib/python3.11/dist-packages (from openmim) (0.4.6)
# Collecting model-index (from openmim)
#   Downloading model_index-0.1.11-py3-none-any.whl.metadata (3.9 kB)
# Collecting opendatalab (from openmim)
#   Downloading opendatalab-0.0.10-py3-none-any.whl.metadata (6.4 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from openmim) (2.2.3)
# Requirement already satisfied: pip>=19.3 in /usr/local/lib/python3.11/dist-packages (from openmim) (24.1.2)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from openmim) (2.32.3)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from openmim) (14.0.0)
# Requirement already satisfied: tabulate in /usr/local/lib/python3.11/dist-packages (from openmim) (0.9.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (6.0.2)
# Requirement already satisfied: markdown in /usr/local/lib/python3.11/dist-packages (from model-index->openmim) (3.7)
# Collecting ordered-set (from model-index->openmim)
#   Downloading ordered_set-4.1.0-py3-none-any.whl.metadata (5.3 kB)
# Requirement already satisfied: pycryptodome in /usr/local/lib/python3.11/dist-packages (from opendatalab->openmim) (3.22.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from opendatalab->openmim) (4.67.1)
# Collecting openxlab (from opendatalab->openmim)
#   Downloading openxlab-0.1.2-py3-none-any.whl.metadata (3.8 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->openmim) (2025.1.31)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->openmim) (2025.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->openmim) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->openmim) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->openmim) (0.1.2)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas->openmim) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas->openmim) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas->openmim) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas->openmim) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas->openmim) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy>=1.23.2->pandas->openmim) (2.4.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->openmim) (1.17.0)
# Collecting filelock~=3.14.0 (from openxlab->opendatalab->openmim)
#   Downloading filelock-3.14.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting oss2~=2.17.0 (from openxlab->opendatalab->openmim)
#   Downloading oss2-2.17.0.tar.gz (259 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 259.5/259.5 kB 8.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: packaging~=24.0 in /usr/local/lib/python3.11/dist-packages (from openxlab->opendatalab->openmim) (24.2)
# Collecting pytz>=2020.1 (from pandas->openmim)
#   Downloading pytz-2023.4-py2.py3-none-any.whl.metadata (22 kB)
# Collecting requests (from openmim)
#   Downloading requests-2.28.2-py3-none-any.whl.metadata (4.6 kB)
# Collecting rich (from openmim)
#   Downloading rich-13.4.2-py3-none-any.whl.metadata (18 kB)
# Collecting setuptools~=60.2.0 (from openxlab->opendatalab->openmim)
#   Downloading setuptools-60.2.0-py3-none-any.whl.metadata (5.1 kB)
# Collecting tqdm (from opendatalab->openmim)
#   Downloading tqdm-4.65.2-py3-none-any.whl.metadata (56 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.0/57.0 kB 3.0 MB/s eta 0:00:00
# Collecting urllib3<1.27,>=1.21.1 (from requests->openmim)
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 2.3 MB/s eta 0:00:00
# Collecting crcmod>=1.7 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading crcmod-1.7.tar.gz (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 4.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting aliyun-python-sdk-kms>=2.4.1 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl.metadata (1.5 kB)
# Collecting aliyun-python-sdk-core>=2.13.12 (from oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading aliyun-python-sdk-core-2.16.0.tar.gz (449 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 449.6/449.6 kB 20.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->pandas->openmim) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy>=1.23.2->pandas->openmim) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy>=1.23.2->pandas->openmim) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy>=1.23.2->pandas->openmim) (2024.2.0)
# Collecting jmespath<1.0.0,>=0.9.3 (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim)
#   Downloading jmespath-0.10.0-py2.py3-none-any.whl.metadata (8.0 kB)
# Requirement already satisfied: cryptography>=3.0.0 in /usr/local/lib/python3.11/dist-packages (from aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (44.0.2)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy>=1.23.2->pandas->openmim) (2024.2.0)
# Requirement already satisfied: cffi>=1.12 in /usr/local/lib/python3.11/dist-packages (from cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.12->cryptography>=3.0.0->aliyun-python-sdk-core>=2.13.12->oss2~=2.17.0->openxlab->opendatalab->openmim) (2.22)
# Downloading openmim-0.3.9-py2.py3-none-any.whl (52 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 52.7/52.7 kB 1.4 MB/s eta 0:00:00
# Downloading model_index-0.1.11-py3-none-any.whl (34 kB)
# Downloading opendatalab-0.0.10-py3-none-any.whl (29 kB)
# Downloading openxlab-0.1.2-py3-none-any.whl (311 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 311.5/311.5 kB 11.5 MB/s eta 0:00:00
# Downloading requests-2.28.2-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.8/62.8 kB 3.0 MB/s eta 0:00:00
# Downloading rich-13.4.2-py3-none-any.whl (239 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 239.4/239.4 kB 9.2 MB/s eta 0:00:00
# Downloading pytz-2023.4-py2.py3-none-any.whl (506 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.5/506.5 kB 24.3 MB/s eta 0:00:00
# Downloading tqdm-4.65.2-py3-none-any.whl (77 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 3.2 MB/s eta 0:00:00
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 7.2 MB/s eta 0:00:00
# Downloading ordered_set-4.1.0-py3-none-any.whl (7.6 kB)
# Downloading filelock-3.14.0-py3-none-any.whl (12 kB)
# Downloading setuptools-60.2.0-py3-none-any.whl (953 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 953.1/953.1 kB 33.6 MB/s eta 0:00:00
# Downloading aliyun_python_sdk_kms-2.16.5-py2.py3-none-any.whl (99 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.5/99.5 kB 4.2 MB/s eta 0:00:00
# Downloading jmespath-0.10.0-py2.py3-none-any.whl (24 kB)
# Building wheels for collected packages: oss2, aliyun-python-sdk-core, crcmod
#   Building wheel for oss2 (setup.py) ... done
#   Created wheel for oss2: filename=oss2-2.17.0-py3-none-any.whl size=112372 sha256=8e3aeb5f16e0f34ad350d11cc565aba3299508591358e7dccb9eef31f3c0ef3e
#   Stored in directory: /root/.cache/pip/wheels/42/79/aa/3671e313c27de35211d345d7a9d8ccb7dde515cf05edba75df
#   Building wheel for aliyun-python-sdk-core (setup.py) ... done
#   Created wheel for aliyun-python-sdk-core: filename=aliyun_python_sdk_core-2.16.0-py3-none-any.whl size=535316 sha256=c873edb47ce7d02e460eb96ec2bae05472e42c5334b3d672424b0102a1e1fab7
#   Stored in directory: /root/.cache/pip/wheels/2b/9a/95/60f111d2a488c5f7f7ed2a96ce407ea57ec7393ddfdec8c956
#   Building wheel for crcmod (setup.py) ... done
#   Created wheel for crcmod: filename=crcmod-1.7-cp311-cp311-linux_x86_64.whl size=31659 sha256=243fa3a4e61d9249b29799f31d1f148c7303a7d427e0828f8d5c753013a94ca4
#   Stored in directory: /root/.cache/pip/wheels/23/94/7a/8cb7d14597e6395ce969933f01aed9ea8fa5f5b4d4c8a61e99
# Successfully built oss2 aliyun-python-sdk-core crcmod
# Installing collected packages: pytz, crcmod, urllib3, tqdm, setuptools, ordered-set, jmespath, filelock, rich, requests, model-index, aliyun-python-sdk-core, aliyun-python-sdk-kms, oss2, openxlab, opendatalab, openmim
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2025.2
#     Uninstalling pytz-2025.2:
#       Successfully uninstalled pytz-2025.2
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.3.0
#     Uninstalling urllib3-2.3.0:
#       Successfully uninstalled urllib3-2.3.0
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: setuptools
#     Found existing installation: setuptools 75.1.0
#     Uninstalling setuptools-75.1.0:
#       Successfully uninstalled setuptools-75.1.0
#   Attempting uninstall: jmespath
#     Found existing installation: jmespath 1.0.1
#     Uninstalling jmespath-1.0.1:
#       Successfully uninstalled jmespath-1.0.1
#   Attempting uninstall: filelock
#     Found existing installation: filelock 3.18.0
#     Uninstalling filelock-3.18.0:
#       Successfully uninstalled filelock-3.18.0
#   Attempting uninstall: rich
#     Found existing installation: rich 14.0.0
#     Uninstalling rich-14.0.0:
#       Successfully uninstalled rich-14.0.0
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.3
#     Uninstalling requests-2.32.3:
#       Successfully uninstalled requests-2.32.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datasets 3.5.0 requires fsspec[http]<=2024.12.0,>=2023.1.0, but you have fsspec 2025.3.2 which is incompatible.
# datasets 3.5.0 requires requests>=2.32.2, but you have requests 2.28.2 which is incompatible.
# datasets 3.5.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# featuretools 1.31.0 requires tqdm>=4.66.3, but you have tqdm 4.65.2 which is incompatible.
# jupyterlab-server 2.27.3 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# nilearn 0.11.1 requires scikit-learn>=1.4.0, but you have scikit-learn 1.2.2 which is incompatible.
# setuptools-scm 8.2.0 requires setuptools>=61, but you have setuptools 60.2.0 which is incompatible.
# preprocessing 0.1.13 requires nltk==3.2.4, but you have nltk 3.9.1 which is incompatible.
# google-colab 1.0.0 requires notebook==6.5.5, but you have notebook 6.5.4 which is incompatible.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.2.3 which is incompatible.
# google-colab 1.0.0 requires requests==2.32.3, but you have requests 2.28.2 which is incompatible.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.29.0 which is incompatible.
# google-spark-connect 0.5.2 requires google-api-core>=2.19.1, but you have google-api-core 1.34.1 which is incompatible.
# pandas-gbq 0.26.1 requires google-api-core<3.0.0dev,>=2.10.2, but you have google-api-core 1.34.1 which is incompatible.
# gcsfs 2024.10.0 requires fsspec==2024.10.0, but you have fsspec 2025.3.2 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.8.4.1 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.3.3.83 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.9.90 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.7.3.90 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.8.93 which is incompatible.
# torch 2.5.1+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.8.93 which is incompatible.
# pytensor 2.27.1 requires filelock>=3.15, but you have filelock 3.14.0 which is incompatible.
# ibis-framework 9.2.0 requires toolz<1,>=0.11, but you have toolz 1.0.0 which is incompatible.
# yfinance 0.2.52 requires requests>=2.31, but you have requests 2.28.2 which is incompatible.
# pymc 5.20.1 requires rich>=13.7.1, but you have rich 13.4.2 which is incompatible.
# plotnine 0.14.5 requires matplotlib>=3.8.0, but you have matplotlib 3.7.5 which is incompatible.
# sphinx 8.1.3 requires requests>=2.30.0, but you have requests 2.28.2 which is incompatible.
# google-cloud-bigtable 2.28.1 requires google-api-core[grpc]<3.0.0dev,>=2.16.0, but you have google-api-core 1.34.1 which is incompatible.
# mlxtend 0.23.4 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# Successfully installed aliyun-python-sdk-core-2.16.0 aliyun-python-sdk-kms-2.16.5 crcmod-1.7 filelock-3.14.0 jmespath-0.10.0 model-index-0.1.11 opendatalab-0.0.10 openmim-0.3.9 openxlab-0.1.2 ordered-set-4.1.0 oss2-2.17.0 pytz-2023.4 requests-2.28.2 rich-13.4.2 setuptools-60.2.0 tqdm-4.65.2 urllib3-1.26.20
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu124/torch2.5.0/index.html
# Collecting mmengine
#   Downloading mmengine-0.10.7-py3-none-any.whl.metadata (20 kB)
# Collecting addict (from mmengine)
#   Downloading addict-2.4.0-py3-none-any.whl.metadata (1.0 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmengine) (3.7.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmengine) (1.26.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmengine) (6.0.2)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mmengine) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from mmengine) (2.5.0)
# Collecting yapf (from mmengine)
#   Downloading yapf-0.43.0-py3-none-any.whl.metadata (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 2.3 MB/s eta 0:00:00
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmengine) (4.11.0.86)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->mmengine) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->mmengine) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->mmengine) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->mmengine) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->mmengine) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->mmengine) (2.4.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine) (2.9.0.post0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine) (2.19.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmengine) (4.3.7)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine) (1.17.0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->mmengine) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->mmengine) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->mmengine) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->mmengine) (2024.2.0)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->mmengine) (2024.2.0)
# Downloading mmengine-0.10.7-py3-none-any.whl (452 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 452.7/452.7 kB 13.8 MB/s eta 0:00:00
# Downloading addict-2.4.0-py3-none-any.whl (3.8 kB)
# Downloading yapf-0.43.0-py3-none-any.whl (256 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 256.2/256.2 kB 12.0 MB/s eta 0:00:00
# Installing collected packages: addict, yapf, mmengine
# Successfully installed addict-2.4.0 mmengine-0.10.7 yapf-0.43.0

# %% [markdown]
# 因为我们没有使用GPU加速。这里只能使用Lite版本的mmcv。

# %%
# !mim install mmcv-lite
# Out:
# Looking in links: https://download.openmmlab.com/mmcv/dist/cu124/torch2.5.0/index.html
# Collecting mmcv-lite
#   Downloading mmcv_lite-2.2.0-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: addict in /usr/local/lib/python3.11/dist-packages (from mmcv-lite) (2.4.0)
# Requirement already satisfied: mmengine>=0.3.0 in /usr/local/lib/python3.11/dist-packages (from mmcv-lite) (0.10.7)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mmcv-lite) (1.26.4)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from mmcv-lite) (24.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mmcv-lite) (11.1.0)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.11/dist-packages (from mmcv-lite) (6.0.2)
# Requirement already satisfied: yapf in /usr/local/lib/python3.11/dist-packages (from mmcv-lite) (0.43.0)
# Requirement already satisfied: opencv-python>=3 in /usr/local/lib/python3.11/dist-packages (from mmcv-lite) (4.11.0.86)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv-lite) (3.7.5)
# Requirement already satisfied: rich in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv-lite) (13.4.2)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.11/dist-packages (from mmengine>=0.3.0->mmcv-lite) (2.5.0)
# Requirement already satisfied: mkl_fft in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-lite) (1.3.8)
# Requirement already satisfied: mkl_random in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-lite) (1.2.4)
# Requirement already satisfied: mkl_umath in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-lite) (0.1.1)
# Requirement already satisfied: mkl in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-lite) (2025.1.0)
# Requirement already satisfied: tbb4py in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-lite) (2022.1.0)
# Requirement already satisfied: mkl-service in /usr/local/lib/python3.11/dist-packages (from numpy->mmcv-lite) (2.4.1)
# Requirement already satisfied: platformdirs>=3.5.1 in /usr/local/lib/python3.11/dist-packages (from yapf->mmcv-lite) (4.3.7)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv-lite) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv-lite) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv-lite) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv-lite) (1.4.8)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv-lite) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mmengine>=0.3.0->mmcv-lite) (2.9.0.post0)
# Requirement already satisfied: intel-openmp<2026,>=2024 in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->mmcv-lite) (2024.2.0)
# Requirement already satisfied: tbb==2022.* in /usr/local/lib/python3.11/dist-packages (from mkl->numpy->mmcv-lite) (2022.1.0)
# Requirement already satisfied: tcmlib==1.* in /usr/local/lib/python3.11/dist-packages (from tbb==2022.*->mkl->numpy->mmcv-lite) (1.2.0)
# Requirement already satisfied: intel-cmplr-lib-rt in /usr/local/lib/python3.11/dist-packages (from mkl_umath->numpy->mmcv-lite) (2024.2.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv-lite) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.11/dist-packages (from rich->mmengine>=0.3.0->mmcv-lite) (2.19.1)
# Requirement already satisfied: intel-cmplr-lib-ur==2024.2.0 in /usr/local/lib/python3.11/dist-packages (from intel-openmp<2026,>=2024->mkl->numpy->mmcv-lite) (2024.2.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.11/dist-packages (from markdown-it-py>=2.2.0->rich->mmengine>=0.3.0->mmcv-lite) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mmengine>=0.3.0->mmcv-lite) (1.17.0)
# Downloading mmcv_lite-2.2.0-py2.py3-none-any.whl (732 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 732.3/732.3 kB 19.5 MB/s eta 0:00:00
# Installing collected packages: mmcv-lite
# Successfully installed mmcv-lite-2.2.0

# %% [markdown]
# # 构建数据加载器

# %% [markdown]
# ## 构建数据集
#
# 接下来, 我们为 MNIST 数据集构建一个数据集类 MNISTDataset, 继承自数据集基类 BaseDataset, 并且重载数据集基类的 load_data_list 函数, 保证返回值为 list[dict]，其中每个 dict 代表一个数据样本。更多关于 MMEngine 中数据集的用法，可以参考数据集教程。

# %%
import numpy as np
from mmcv.transforms import to_tensor
from torch.utils.data import random_split
from torchvision.datasets import MNIST

from mmengine.dataset import BaseDataset


class MNISTDataset(BaseDataset):

    def __init__(self, data_root, pipeline, test_mode=False):
        # 下载 MNIST 数据集
        if test_mode:
            mnist_full = MNIST(data_root, train=True, download=True)
            self.mnist_dataset, _ = random_split(mnist_full, [55000, 5000])
        else:
            self.mnist_dataset = MNIST(data_root, train=False, download=True)

        super().__init__(
            data_root=data_root, pipeline=pipeline, test_mode=test_mode)

    @staticmethod
    def totensor(img):
        if len(img.shape) < 3:
            img = np.expand_dims(img, -1)
        img = np.ascontiguousarray(img.transpose(2, 0, 1))
        return to_tensor(img)

    def load_data_list(self):
        return [
            dict(inputs=self.totensor(np.array(x[0]))) for x in self.mnist_dataset
        ]


dataset = MNISTDataset("./data", [])
# Out:
# Downloading http://yann.lecun.com/exdb/mnist/train-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-images-idx3-ubyte.gz to ./data/MNIST/raw/train-images-idx3-ubyte.gz
# 100%|██████████| 9.91M/9.91M [00:00<00:00, 11.6MB/s]
# Extracting ./data/MNIST/raw/train-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/train-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/train-labels-idx1-ubyte.gz to ./data/MNIST/raw/train-labels-idx1-ubyte.gz
# 100%|██████████| 28.9k/28.9k [00:00<00:00, 344kB/s]
# Extracting ./data/MNIST/raw/train-labels-idx1-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-images-idx3-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw/t10k-images-idx3-ubyte.gz
# 100%|██████████| 1.65M/1.65M [00:00<00:00, 3.22MB/s]
# Extracting ./data/MNIST/raw/t10k-images-idx3-ubyte.gz to ./data/MNIST/raw
#
# Downloading http://yann.lecun.com/exdb/mnist/t10k-labels-idx1-ubyte.gz
# Failed to download (trying next):
# HTTP Error 404: Not Found
#
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz
# Downloading https://ossci-datasets.s3.amazonaws.com/mnist/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz
# 100%|██████████| 4.54k/4.54k [00:00<00:00, 7.64MB/s]
# Extracting ./data/MNIST/raw/t10k-labels-idx1-ubyte.gz to ./data/MNIST/raw

# %% [markdown]
# 使用 Runner 中的函数 build_dataloader 来构建数据加载器。

# %%
import os
import torch
from mmengine.runner import Runner

NUM_WORKERS = int(os.cpu_count() / 2)
BATCH_SIZE = 256 if torch.cuda.is_available() else 64

train_dataloader = dict(
    batch_size=BATCH_SIZE,
    num_workers=NUM_WORKERS,
    persistent_workers=True,
    sampler=dict(type='DefaultSampler', shuffle=True),
    dataset=dataset)
train_dataloader = Runner.build_dataloader(train_dataloader)
# Out:
# /usr/local/lib/python3.11/dist-packages/mmengine/optim/optimizer/zero_optimizer.py:11: DeprecationWarning: `TorchScript` support for functional optimizers is deprecated and will be removed in a future PyTorch release. Consider using the `torch.compile` optimizer instead.
#   from torch.distributed.optim import \

# %% [markdown]
# # 构建生成器网络和判别器网络

# %% [markdown]
# 下面的代码构建并实例化了一个生成器(Generator)和一个判别器(Discriminator)。

# %%
# 导入 PyTorch 神经网络模块 torch.nn，并将其命名为 nn。
# 这个模块包含了构建神经网络所需的各种类，例如线性层、批归一化层、激活函数等。
import torch.nn as nn

class Generator(nn.Module):
    '''
    定义了一个名为 Generator 的类，它继承自 nn.Module。
    在 PyTorch 中，所有的神经网络模块都应该继承自 nn.Module。
    这使得 Generator 类能够拥有 PyTorch 神经网络的各种功能。
    '''
    
    def __init__(self, noise_size, img_shape):
        '''
        这是 Generator 类的构造函数。当创建一个 Generator 类的实例时，这个函数会被调用。它接收两个参数：
        
        Args:
        noise_size: 生成器输入噪声向量的维度。
        img_shape: 生成器输出图像的形状，例如 (1, 28, 28) 表示单通道（灰度）、28x28 像素的图像。
        '''

        # 调用父类 nn.Module 的构造函数。
        # 这是必须的，以确保 Generator 类正确地初始化其父类的属性和方法。
        super().__init__()

        # 将传入的图像形状 img_shape 保存为 Generator 实例的一个属性。
        # 这样在 Generator 类的其他方法中就可以方便地访问图像的形状。
        self.img_shape = img_shape
        # 将传入的噪声向量维度 noise_size 保存为 Generator 实例的一个属性。
        # 这在定义生成器的网络结构时会用到。
        self.noise_size = noise_size

        def block(in_feat, out_feat, normalize=True):
            '''
            定义一个名为 block 的内部函数。
            这个函数用于创建一个包含一个线性层、一个可选的批归一化层和一个 LeakyReLU 激活层的序列。
            这个模块化的设计使得构建生成器的层变得更加简洁。

            Args:
            in_feat: 输入特征的维度。
            out_feat: 输出特征的维度。
            normalize: 一个布尔值，指示是否在线性层之后添加批归一化层，默认为 True。
            '''

            # 在 block 函数内部，首先创建一个包含一个线性层的列表。
            # nn.Linear(in_feat, out_feat) 定义了一个从 in_feat 维输入到 out_feat 维输出的全连接层。
            layers = [nn.Linear(in_feat, out_feat)]

            # 如果 normalize 为 True，则向 layers 列表中添加一个 nn.BatchNorm1d 层。
            # 批归一化层有助于加速训练并提高模型的稳定性。
            # out_feat 指定了批归一化层的输入维度，0.8 是动量（momentum）参数，用于计算移动平均和移动方差。
            if normalize:
                layers.append(nn.BatchNorm1d(out_feat, 0.8))

            # 无论是否添加了批归一化层，都会向 layers 列表中添加一个 LeakyReLU 激活函数。
            # LeakyReLU 是一种非线性激活函数，有助于模型学习复杂的模式。
            # 0.2 是负斜率的系数，inplace=True 表示直接在输入上进行修改，以节省内存。
            layers.append(nn.LeakyReLU(0.2, inplace=True))

            # block 函数返回包含所创建的层的列表。
            return layers

        # 创建一个 nn.Sequential 容器，它会将接收到的模块按顺序组合成一个新的模块。
        # nn.Sequential 是 PyTorch 中一个非常有用的容器，它允许你按顺序组合多个神经网络层。输入数据会依次通过这些层。
        # 这个 self.model 就是生成器的主要网络结构。
        self.model = nn.Sequential(
            # 调用之前定义的 block 函数，创建了一个输入维度为 noise_size，输出维度为 128 的线性层，并且没有使用批归一化 (normalize=False)。
            # * 运算符用于将 block 函数返回的列表中的各个层作为 nn.Sequential 的子模块。
            *block(noise_size, 128, normalize=False),
            # 再次调用 block 函数，创建了一个输入维度为 128，输出维度为 256 的线性层，并使用了默认的批归一化 (normalize=True)。
            *block(128, 256),
            *block(256, 512),
            *block(512, 1024),
            # 添加一个线性层，其输入维度为 1024，输出维度为图像像素的总数。
            # np.prod(img_shape) 计算了图像形状 img_shape 中所有元素的乘积，例如对于 (1, 28, 28)，结果是 1×28×28=784。
            nn.Linear(1024, int(np.prod(img_shape))),
            # 添加一个 Tanh 激活函数。
            # Tanh 函数的输出范围在 -1 到 1 之间，通常用在生成器的最后一层，以将生成的像素值缩放到这个范围内。
            nn.Tanh(),
        )

    def forward(self, z):
        '''
        定义 Generator 类的前向传播方法 forward。
        当给生成器输入一个噪声向量时，这个方法会被调用。
        z 是输入的噪声向量。
        '''

        # 将输入的噪声向量 z 通过之前定义的 self.model 网络结构进行前向传播。
        # self.model 会按顺序执行其中包含的各个层，最终得到一个输出张量 img，这个张量表示生成的“扁平化”的图像。
        img = self.model(z)
        # 对 img 张量进行形状变换（reshape）。
        # img.size(0) 获取了批次大小（batch size），*self.img_shape 将之前保存的图像形状展开作为新的形状参数。
        # 例如，如果 img 的形状是 (batch_size, 784) 且 self.img_shape 是 (1, 28, 28)，那么 img 的形状会被变换为 (batch_size, 1, 28, 28)，即生成了一批指定形状的图像。
        img = img.view(img.size(0), *self.img_shape)
        # 返回最终生成的图像张量 img。
        return img

# %% [markdown]
# ## 前向传播
#
# 在PyTorch中，forward函数是定义模型前向传播逻辑的核心函数。它定义了前向传播的过程，也就是输入数据经过这些层之后得到输出的过程。它的作用及调用机制如下：
#
# 1. forward函数的作用
#    **前向传播逻辑**：forward函数定义了输入数据如何通过模型的各个层（如卷积层、全连接层等）逐步变换为输出。
#    **不直接操作数据**：你不需要手动调用forward()，也不应直接操作输入张量的requires_grad属性，PyTorch会自动处理梯度计算。
#
# 2. forward的调用机制
#
#     **通过__call__隐式调用**：
#     当你将输入数据传递给继承自`nn.Module`的模型实例时（例如`img = model(z)`），PyTorch的`nn.Module`基类会通过其`__call__`方法自动调用`forward`函数。
#
#     **__call__的额外操作**：
#     在调用`forward`之前，`__call__`还会执行一些内部管理操作。

# %%
class Discriminator(nn.Module):
    '''
    定义一个名为 Discriminator 的类。
    这个类继承自 torch.nn.Module，这是在 PyTorch 中构建神经网络模型的标准做法。
    通过继承 nn.Module，Discriminator 类将拥有 PyTorch 神经网络模块的基本功能和属性。
    '''
    def __init__(self, img_shape):
        '''
        定义类的构造函数 __init__。
        每当你创建一个 Discriminator 类的实例时，这个函数会被自动调用。
        它接收一个参数 img_shape，这个参数很可能是一个包含图像维度信息的元组。
        例如，对于一个 28x28 的灰度图像，img_shape 可能是 (1, 28, 28)，或者对于一个 32x32 的 RGB 图像，可能是 (3, 32, 32)。
        '''
        super().__init__()

        # 创建一个 nn.Sequential 对象，并将其赋值给 self.model。
        self.model = nn.Sequential(
            # 定义 nn.Sequential 中的第一个神经网络层，它是一个线性层（全连接层）。
            # * np.prod(img_shape): np.prod() 是 NumPy 库中的一个函数，它计算给定数组中所有元素的乘积。
            #   在这里，img_shape （例如 (1, 28, 28)）的所有维度相乘的结果就是图像的总像素数（例如 1×28×28=784）。
            #   int() 将结果转换为整数。
            #   这个值作为 nn.Linear 的第一个参数，表示输入到这个线性层的特征数量，也就是展平后的图像像素数。
            # 512: 这是 nn.Linear 的第二个参数，表示这个线性层的输出特征数量，也就是将输入展平的图像映射到一个 512 维的向量空间。
            nn.Linear(int(np.prod(img_shape)), 512),
            # 定义 nn.Sequential 中的第二个层，它是一个 Leaky ReLU 激活函数。
            # * nn.LeakyReLU(0.2): Leaky ReLU 是一种非线性激活函数，它在输入小于零时也允许一个小的梯度通过，以解决 ReLU 函数可能出现的“死亡 ReLU”问题。
            #   这里的 0.2 是负斜率的系数。
            # * inplace=True: 这个参数表示进行原地操作，即直接修改输入的值，而不是创建一个新的输出。
            #   这可以节省内存。
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Linear(256, 1),
            # 定义 nn.Sequential 中的第六个层，它是一个 Sigmoid 激活函数。
            # Sigmoid 函数将输入值压缩到 0 到 1 的范围内。
            # 在判别器中，这个输出值可以被解释为输入图像是真实样本的概率，值越接近 1 表示判别器认为图像越真实，值越接近 0 表示判别器认为图像是生成的。
            nn.Sigmoid(),
        )

    def forward(self, img):
        '''
        定义 Discriminator 类的前向传播方法 forward。
        当输入数据传递给 Discriminator 实例时，这个方法会被自动调用。
        它接收一个参数 img，这通常是一个表示输入图像的 PyTorch 张量。
        '''

        # 对输入的图像张量 img 进行形状变换（reshape）。
        # * img.size(0): 这获取了 img 张量的第一个维度的大小，通常是批次大小（batch size）。
        # * -1: 这表示让 PyTorch 自动计算剩余维度的大小，以保证元素的总数不变。
        #   因此，img.view(img.size(0), -1) 的作用是将输入的图像张量展平成一个二维张量，其形状为 (batch_size, num_pixels)，其中 num_pixels 是图像的总像素数。
        img_flat = img.view(img.size(0), -1)
        # 将展平后的图像数据 img_flat 作为输入传递给 self.model，也就是之前定义的 nn.Sequential 模块。
        # 数据会依次通过 self.model 中定义的线性层和激活函数。
        # 最终的输出 validity 是一个形状为 (batch_size, 1) 的张量，其中每个元素表示对应输入图像被判别器认为是真实图像的概率。
        validity = self.model(img_flat)

        # 返回判别器的输出 validity。
        return validity

# %%
# 100 表明生成器将接收一个长度为 100 的随机数数组作为输入。
# 它是生成新图像的种子或潜在空间。
# noise_size 定义了输入到生成器网络的随机噪声向量的维度。
# 可以将这个 100 维的噪声向量想象成编码了生成图像的各种潜在特征。
# 虽然我们人类很难直接理解这 100 个维度分别代表什么，但网络在训练过程中会学习如何将这些维度组合起来，控制生成图像的高级属性，比如图像的整体风格、某些物体的形状、颜色等等。
# 可以把它想象成这样：
#    你有一个包含 100 个旋钮的魔法盒子（噪声向量）。
#    每个旋钮控制着图像的不同方面（潜在特征）。
#    生成器网络就像一个复杂的机器，它知道如何调整这 100 个旋钮，最终组合成一幅完整的图像。
#    每次你随机设置这 100 个旋钮的值，魔法盒子就会产生一张新的图像。

# (1, 28, 28) 表明生成器的目标是生成形状为单通道（灰度）、28x28 像素的图像。
generator = Generator(100, (1, 28, 28))

# 在创建实例的过程中，它通过传递 (1, 28, 28) 这个元组，告诉判别器的 __init__ 方法，这个判别器将要处理的图像的形状是 1 通道、28x28 像素的。
discriminator = Discriminator((1, 28, 28))

# %% [markdown]
# # 构建一个生成对抗网络模型
#
# 在使用 MMEngine 时，我们用 [ImgDataPreprocessor](https://mmengine.readthedocs.io/zh-cn/latest/api/generated/mmengine.model.ImgDataPreprocessor.html#mmengine.model.ImgDataPreprocessor) 来对数据进行归一化和颜色通道的转换。

# %% [markdown]
# ## ImgDataPreprocessor
#
# MMEngine提供的一个用于归一化和 bgr 转 rgb 转换的图像预处理程序。
#
# 接收数据加载器采样的数据，并将其预处理为模型输入格式。 ImgDataPreprocessor 提供以下基本数据预处理：
#
# * 将数据收集并移动到目标设备。
# * 如果输入形状为（3，H，W），则将输入从 bgr 转换为 rgb。
# * 使用定义的均值和标准差对图像进行归一化。
# * 使用定义的 pad_value 将输入填充到当前批次的最大尺寸。填充大小可以是定义的 pad_size_divisor 的倍数。
# * 将输入堆叠到 batch_inputs 中。
#
# 对于 ImgDataPreprocessor ，单个输入的维度必须是 (3, H, W)。

# %%
from mmengine.model import ImgDataPreprocessor

data_preprocessor = ImgDataPreprocessor(mean=([127.5]), std=([127.5]))

# %% [markdown]
# ### 127.5
#
# 对于将像素值从 [0,255] 范围标准化到 [−1,1] 范围，通常会进行以下操作：
#
# * 中心化 (Centering): 从每个像素值中减去一个均值。
# * 缩放 (Scaling): 将结果除以一个标准差或者一个固定的范围值。
#
# 上面例子中，默认值 127.5 很可能被用作中心化的均值，并且假设像素值的原始范围是 [0,255]。如果目标范围是 [−1,1]，那么缩放因子很可能是 127.5。

# %% [markdown]
# ## 基础 GAN 算法
#
# 下面的代码实现了基础 GAN 的算法。使用 MMEngine 实现算法类，需要继承 [BaseModel](https://mmengine.readthedocs.io/zh-cn/latest/api/generated/mmengine.model.BaseModel.html#mmengine.model.BaseModel) 基类，在 train_step 中实现训练过程。GAN 需要交替训练生成器和判别器，分别由 train_discriminator 和 train_generator 实现，并实现 disc_loss 和 gen_loss 计算判别器损失函数和生成器损失函数。 关于 BaseModel 的更多信息，请参考[模型教程](https://mmengine.readthedocs.io/zh-cn/latest/tutorials/model.html).

# %%
import torch.nn.functional as F
from mmengine.model import BaseModel

class GAN(BaseModel):

    def __init__(self, generator, discriminator, noise_size,
                 data_preprocessor):
        super().__init__(data_preprocessor=data_preprocessor)
        assert generator.noise_size == noise_size
        self.generator = generator
        self.discriminator = discriminator
        self.noise_size = noise_size

    def train_step(self, data, optim_wrapper):
        '''
        实现默认模型训练过程，包括预处理、模型前向传播、损失计算、优化和反向传播。

        Args:
        data: 从数据集中采样的数据。即下文中传入 Runner 的 train_dataloader 。
        optim_wrapper: 是用于更新模型参数的 OptimWrapper 实例。详见后续的“优化器”的章节
        '''
        
        # 获取数据和数据预处理
        # 如果忘记了，这是上一节中的 ImgDataPreprocessor
        inputs_dict = self.data_preprocessor(data, True)
        
        # 训练判别器
        disc_optimizer_wrapper = optim_wrapper['discriminator']
        with disc_optimizer_wrapper.optim_context(self.discriminator):
            log_vars = self.train_discriminator(inputs_dict,
                                                disc_optimizer_wrapper)

        # 训练生成器
        ## 训练生成器时冻结判别器
        ## 避免梯度冗余计算：生成器的训练仅需反向传播到自身参数，无需更新判别器。关闭判别器梯度可减少计算量和内存占用。
        ## 稳定对抗训练：防止判别器在生成器训练时被意外更新，确保二者交替优化。生成器的目标是“欺骗”当前固定的判别器，而非适配一个动态变化的判别器。
        set_requires_grad(self.discriminator, False)
        gen_optimizer_wrapper = optim_wrapper['generator']
        with gen_optimizer_wrapper.optim_context(self.generator):
            log_vars_gen = self.train_generator(inputs_dict,
                                                gen_optimizer_wrapper)

        ## 恢复判别器梯度以训练判别器
        set_requires_grad(self.discriminator, True)
        log_vars.update(log_vars_gen)

        return log_vars

    def forward(self, batch_inputs, data_samples=None, mode=None):
        return self.generator(batch_inputs)

    # 用于 discriminator 的损失函数
    def disc_loss(self, disc_pred_fake, disc_pred_real):
        losses_dict = dict()
        # 判别器对生成样本的预测值（期望接近0）
        ## 等同于 torch.zeros_like(disc_pred_fake)
        losses_dict['loss_disc_fake'] = F.binary_cross_entropy(
            disc_pred_fake, 0. * torch.ones_like(disc_pred_fake))
        # 判别器对真实样本的预测值（期望接近1）。
        losses_dict['loss_disc_real'] = F.binary_cross_entropy(
            disc_pred_real, 1. * torch.ones_like(disc_pred_real))

        loss, log_var = self.parse_losses(losses_dict)
        return loss, log_var

    # 用于 generator 的损失函数
    def gen_loss(self, disc_pred_fake):
        losses_dict = dict()
        losses_dict['loss_gen'] = F.binary_cross_entropy(
            disc_pred_fake, 1. * torch.ones_like(disc_pred_fake))
        loss, log_var = self.parse_losses(losses_dict)
        return loss, log_var

    def train_discriminator(self, inputs, optimizer_wrapper):
        real_imgs = inputs['inputs']
        z = torch.randn(
            (real_imgs.shape[0], self.noise_size)).type_as(real_imgs)
        with torch.no_grad():
            fake_imgs = self.generator(z)

        disc_pred_fake = self.discriminator(fake_imgs)
        disc_pred_real = self.discriminator(real_imgs)

        parsed_losses, log_vars = self.disc_loss(disc_pred_fake,
                                                 disc_pred_real)
        optimizer_wrapper.update_params(parsed_losses)
        return log_vars

    def train_generator(self, inputs, optimizer_wrapper):
        real_imgs = inputs['inputs']
        z = torch.randn(real_imgs.shape[0], self.noise_size).type_as(real_imgs)

        fake_imgs = self.generator(z)

        disc_pred_fake = self.discriminator(fake_imgs)
        parsed_loss, log_vars = self.gen_loss(disc_pred_fake)

        optimizer_wrapper.update_params(parsed_loss)
        return log_vars

# 函数 set_requires_grad 用来锁定训练生成器时判别器的权重。
# 通过控制梯度计算来优化训练过程。
def set_requires_grad(nets, requires_grad=False):
    """Set requires_grad for all the networks.

    Args:
        nets (nn.Module | list[nn.Module]): A list of networks or a single
            network.
        requires_grad (bool): Whether the networks require gradients or not.
    """
    if not isinstance(nets, list):
        nets = [nets]
    for net in nets:
        if net is not None:
            for param in net.parameters():
                param.requires_grad = requires_grad

# %%
model = GAN(generator, discriminator, 100, data_preprocessor)

# %% [markdown]
# # 构建优化器

# %% [markdown]
# MMEngine 使用 [OptimWrapper](https://mmengine.readthedocs.io/zh-cn/latest/api/generated/mmengine.optim.OptimWrapper.html#mmengine.optim.OptimWrapper) 来封装优化器，对于多个优化器的情况，使用 [OptimWrapperDict](https://mmengine.readthedocs.io/zh-cn/latest/api/generated/mmengine.optim.OptimWrapperDict.html#mmengine.optim.OptimWrapperDict) 对 OptimWrapper 再进行一次封装。 关于优化器的更多信息，请参考[优化器教程](https://mmengine.readthedocs.io/zh-cn/latest/tutorials/optim_wrapper.html).

# %% [markdown]
# 在GAN的训练中，优化器（Optimizer）的作用是通过梯度下降算法更新生成器（Generator）和判别器（Discriminator）的模型参数，使它们朝着最小化各自损失函数的方向优化。
#
# GAN的训练本质是参数优化问题
#
# GAN的生成器和判别器是两个独立的神经网络，它们的参数需要通过反向传播和梯度下降来更新：
#
# * 生成器的目标：生成尽可能逼真的样本，让判别器无法区分真假。
# * 判别器的目标：准确区分真实样本和生成样本。
# * 优化器的作用：根据损失函数计算的梯度，调整模型参数以逐步逼近目标。
#
# Adam（Adaptive Moment Estimation）是一种基于梯度下降的优化算法，可以看作是传统随机梯度下降（SGD）的增强版本。

# %%
from mmengine.optim import OptimWrapper, OptimWrapperDict

opt_g = torch.optim.Adam(
    generator.parameters(), lr=0.0001, betas=(0.5, 0.999))
opt_g_wrapper = OptimWrapper(opt_g)

opt_d = torch.optim.Adam(
    discriminator.parameters(), lr=0.0001, betas=(0.5, 0.999))
opt_d_wrapper = OptimWrapper(opt_d)

opt_wrapper_dict = OptimWrapperDict(
    generator=opt_g_wrapper, discriminator=opt_d_wrapper)

# %% [markdown]
# # 使用执行器进行训练

# %% [markdown]
# 下面的代码演示了如何使用 Runner 进行模型训练。关于 [Runner](https://mmengine.readthedocs.io/zh-cn/latest/api/generated/mmengine.runner.Runner.html#mmengine.runner.Runner) 的更多信息，请参考[执行器教程](https://mmengine.readthedocs.io/zh-cn/latest/tutorials/runner.html)。

# %%
train_cfg = dict(by_epoch=True, max_epochs=220)
runner = Runner(
    model,
    work_dir='runs/gan/',
    train_dataloader=train_dataloader,
    train_cfg=train_cfg,
    # 计算模型参数的梯度。与 train_dataloader 配合使用。
    optim_wrapper=opt_wrapper_dict)
runner.train()
# Out:
# 04/22 05:31:47 - mmengine - INFO -
# ------------------------------------------------------------
# System environment:
#     sys.platform: linux
#     Python: 3.11.11 (main, Dec  4 2024, 08:55:07) [GCC 11.4.0]
#     CUDA available: False
#     MUSA available: False
#     numpy_random_seed: 166047967
#     GCC: x86_64-linux-gnu-gcc (Ubuntu 11.4.0-1ubuntu1~22.04) 11.4.0
#     PyTorch: 2.5.1+cu124
#     PyTorch compiling details: PyTorch built with:
#   - GCC 9.3
#   - C++ Version: 201703
#   - Intel(R) oneAPI Math Kernel Library Version 2025.1-Product Build 20250306 for Intel(R) 64 architecture applications
#   - Intel(R) MKL-DNN v3.5.3 (Git Hash 66f0cb9eb66affd2da3bf5f8d897376f04aae6af)
#   - OpenMP 201511 (a.k.a. OpenMP 4.5)
#   - LAPACK is enabled (usually provided by MKL)
#   - NNPACK is enabled
#   - CPU capability usage: AVX2
#   - Build settings: BLAS_INFO=mkl, BUILD_TYPE=Release, CUDA_VERSION=12.4, CUDNN_VERSION=9.1.0, CXX_COMPILER=/opt/rh/devtoolset-9/root/usr/bin/c++, CXX_FLAGS= -D_GLIBCXX_USE_CXX11_ABI=0 -fabi-version=11 -fvisibility-inlines-hidden -DUSE_PTHREADPOOL -DNDEBUG -DUSE_KINETO -DLIBKINETO_NOROCTRACER -DLIBKINETO_NOXPUPTI=ON -DUSE_FBGEMM -DUSE_PYTORCH_QNNPACK -DUSE_XNNPACK -DSYMBOLICATE_MOBILE_DEBUG_HANDLE -O2 -fPIC -Wall -Wextra -Werror=return-type -Werror=non-virtual-dtor -Werror=bool-operation -Wnarrowing -Wno-missing-field-initializers -Wno-type-limits -Wno-array-bounds -Wno-unknown-pragmas -Wno-unused-parameter -Wno-strict-overflow -Wno-strict-aliasing -Wno-stringop-overflow -Wsuggest-override -Wno-psabi -Wno-error=old-style-cast -Wno-missing-braces -fdiagnostics-color=always -faligned-new -Wno-unused-but-set-variable -Wno-maybe-uninitialized -fno-math-errno -fno-trapping-math -Werror=format -Wno-stringop-overflow, LAPACK_INFO=mkl, PERF_WITH_AVX=1, PERF_WITH_AVX2=1, TORCH_VERSION=2.5.1, USE_CUDA=ON, USE_CUDNN=ON, USE_CUSPARSELT=1, USE_EXCEPTION_PTR=1, USE_GFLAGS=OFF, USE_GLOG=OFF, USE_GLOO=ON, USE_MKL=ON, USE_MKLDNN=ON, USE_MPI=OFF, USE_NCCL=1, USE_NNPACK=ON, USE_OPENMP=ON, USE_ROCM=OFF, USE_ROCM_KERNEL_ASSERT=OFF,
#
#     TorchVision: 0.20.1+cu124
#     OpenCV: 4.11.0
#     MMEngine: 0.10.7
#
# Runtime environment:
#     dist_cfg: {'backend': 'nccl'}
#     seed: 166047967
#     Distributed launcher: none
#     Distributed training: False
#     GPU number: 1
# ------------------------------------------------------------
#
# 04/22 05:31:47 - mmengine - INFO - Distributed training is not used, all SyncBatchNorm (SyncBN) layers in the model will be automatically reverted to BatchNormXd layers if they are used.
# 04/22 05:31:47 - mmengine - INFO - Hooks will be executed in the following order:
# before_run:
# (VERY_HIGH   ) RuntimeInfoHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# before_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_train_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (NORMAL      ) DistSamplerSeedHook
#  --------------------
# before_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
#  --------------------
# after_train_iter:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_train_epoch:
# (NORMAL      ) IterTimerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_val_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_val_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_val_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_val_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
# (LOW         ) ParamSchedulerHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# after_val:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_train:
# (VERY_HIGH   ) RuntimeInfoHook
# (VERY_LOW    ) CheckpointHook
#  --------------------
# before_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# before_test_epoch:
# (NORMAL      ) IterTimerHook
#  --------------------
# before_test_iter:
# (NORMAL      ) IterTimerHook
#  --------------------
# after_test_iter:
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test_epoch:
# (VERY_HIGH   ) RuntimeInfoHook
# (NORMAL      ) IterTimerHook
# (BELOW_NORMAL) LoggerHook
#  --------------------
# after_test:
# (VERY_HIGH   ) RuntimeInfoHook
#  --------------------
# after_run:
# (BELOW_NORMAL) LoggerHook
#  --------------------
# 04/22 05:31:47 - mmengine - WARNING - "FileClient" will be deprecated in future. Please use io functions in https://mmengine.readthedocs.io/en/latest/api/fileio.html#file-io
# 04/22 05:31:47 - mmengine - WARNING - "HardDiskBackend" is the alias of "LocalBackend" and the former will be deprecated in future.
# 04/22 05:31:47 - mmengine - INFO - Checkpoints will be saved to /kaggle/working/runs/gan.
# 04/22 05:31:48 - mmengine - INFO - Epoch(train)   [1][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:59:08  time: 0.1028  data_time: 0.0492  loss: 0.6737  loss_disc_fake: 0.7134  loss_disc_real: 0.3344  loss_gen: 0.6737
# 04/22 05:31:48 - mmengine - INFO - Epoch(train)   [1][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:49:31  time: 0.0694  data_time: 0.0328  loss: 0.6433  loss_disc_fake: 0.7474  loss_disc_real: 0.0575  loss_gen: 0.6433
# 04/22 05:31:49 - mmengine - INFO - Epoch(train)   [1][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:46:33  time: 0.0707  data_time: 0.0345  loss: 0.6046  loss_disc_fake: 0.7999  loss_disc_real: 0.0283  loss_gen: 0.6046
# 04/22 05:31:50 - mmengine - INFO - Epoch(train)   [1][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:44:39  time: 0.0678  data_time: 0.0338  loss: 0.6141  loss_disc_fake: 0.7986  loss_disc_real: 0.0488  loss_gen: 0.6141
# 04/22 05:31:51 - mmengine - INFO - Epoch(train)   [1][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:44:06  time: 0.0731  data_time: 0.0376  loss: 0.6199  loss_disc_fake: 0.7962  loss_disc_real: 0.0873  loss_gen: 0.6199
# 04/22 05:31:51 - mmengine - INFO - Epoch(train)   [1][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:43:05  time: 0.0661  data_time: 0.0317  loss: 0.5977  loss_disc_fake: 0.8375  loss_disc_real: 0.1317  loss_gen: 0.5977
# 04/22 05:31:52 - mmengine - INFO - Epoch(train)   [1][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:43:03  time: 0.0747  data_time: 0.0358  loss: 0.5934  loss_disc_fake: 0.8669  loss_disc_real: 0.1920  loss_gen: 0.5934
# 04/22 05:31:53 - mmengine - INFO - Epoch(train)   [1][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:43:16  time: 0.0783  data_time: 0.0384  loss: 0.5799  loss_disc_fake: 0.9018  loss_disc_real: 0.2540  loss_gen: 0.5799
# 04/22 05:31:54 - mmengine - INFO - Epoch(train)   [1][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:43:38  time: 0.0811  data_time: 0.0405  loss: 0.6005  loss_disc_fake: 0.8817  loss_disc_real: 0.3403  loss_gen: 0.6005
# 04/22 05:31:54 - mmengine - INFO - Epoch(train)   [1][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:43:21  time: 0.0714  data_time: 0.0344  loss: 0.6528  loss_disc_fake: 0.8430  loss_disc_real: 0.3808  loss_gen: 0.6528
# 04/22 05:31:55 - mmengine - INFO - Epoch(train)   [1][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:43:33  time: 0.0795  data_time: 0.0420  loss: 0.6790  loss_disc_fake: 0.8205  loss_disc_real: 0.4203  loss_gen: 0.6790
# 04/22 05:31:56 - mmengine - INFO - Epoch(train)   [1][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:43:30  time: 0.0751  data_time: 0.0400  loss: 0.7400  loss_disc_fake: 0.7619  loss_disc_real: 0.4181  loss_gen: 0.7400
# 04/22 05:31:56 - mmengine - INFO - Epoch(train)   [1][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:43:04  time: 0.0665  data_time: 0.0328  loss: 0.7282  loss_disc_fake: 0.7726  loss_disc_real: 0.4407  loss_gen: 0.7282
# 04/22 05:31:57 - mmengine - INFO - Epoch(train)   [1][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:55  time: 0.0716  data_time: 0.0353  loss: 0.7728  loss_disc_fake: 0.7378  loss_disc_real: 0.4244  loss_gen: 0.7728
# 04/22 05:31:58 - mmengine - INFO - Epoch(train)   [1][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:45  time: 0.0709  data_time: 0.0342  loss: 0.8219  loss_disc_fake: 0.7235  loss_disc_real: 0.4032  loss_gen: 0.8219
# 04/22 05:31:58 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:31:58 - mmengine - INFO - Saving checkpoint at 1 epochs
# 04/22 05:31:58 - mmengine - WARNING - `save_param_scheduler` is True but `self.param_schedulers` is None, so skip saving parameter schedulers
# 04/22 05:31:59 - mmengine - INFO - Epoch(train)   [2][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:53  time: 0.0882  data_time: 0.0512  loss: 0.8218  loss_disc_fake: 0.7196  loss_disc_real: 0.4217  loss_gen: 0.8218
# 04/22 05:32:00 - mmengine - INFO - Epoch(train)   [2][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:51  time: 0.0743  data_time: 0.0383  loss: 0.8675  loss_disc_fake: 0.7084  loss_disc_real: 0.4122  loss_gen: 0.8675
# 04/22 05:32:01 - mmengine - INFO - Epoch(train)   [2][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:44  time: 0.0715  data_time: 0.0363  loss: 0.8634  loss_disc_fake: 0.7162  loss_disc_real: 0.3985  loss_gen: 0.8634
# 04/22 05:32:01 - mmengine - INFO - Epoch(train)   [2][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:46  time: 0.0760  data_time: 0.0405  loss: 0.8694  loss_disc_fake: 0.7355  loss_disc_real: 0.4048  loss_gen: 0.8694
# 04/22 05:32:02 - mmengine - INFO - Epoch(train)   [2][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:56  time: 0.0815  data_time: 0.0458  loss: 0.9296  loss_disc_fake: 0.6804  loss_disc_real: 0.3582  loss_gen: 0.9296
# 04/22 05:32:03 - mmengine - INFO - Epoch(train)   [2][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:54  time: 0.0739  data_time: 0.0383  loss: 0.9162  loss_disc_fake: 0.7160  loss_disc_real: 0.3427  loss_gen: 0.9162
# 04/22 05:32:04 - mmengine - INFO - Epoch(train)   [2][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:59  time: 0.0793  data_time: 0.0424  loss: 0.8978  loss_disc_fake: 0.6987  loss_disc_real: 0.3312  loss_gen: 0.8978
# 04/22 05:32:05 - mmengine - INFO - Epoch(train)   [2][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:59  time: 0.0750  data_time: 0.0399  loss: 0.9638  loss_disc_fake: 0.6431  loss_disc_real: 0.2973  loss_gen: 0.9638
# 04/22 05:32:05 - mmengine - INFO - Epoch(train)   [2][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:43:09  time: 0.0834  data_time: 0.0462  loss: 0.9883  loss_disc_fake: 0.6398  loss_disc_real: 0.2721  loss_gen: 0.9883
# 04/22 05:32:06 - mmengine - INFO - Epoch(train)   [2][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:43:03  time: 0.0714  data_time: 0.0367  loss: 0.9763  loss_disc_fake: 0.7332  loss_disc_real: 0.3085  loss_gen: 0.9763
# 04/22 05:32:07 - mmengine - INFO - Epoch(train)   [2][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:55  time: 0.0695  data_time: 0.0327  loss: 1.0099  loss_disc_fake: 0.6535  loss_disc_real: 0.3802  loss_gen: 1.0099
# 04/22 05:32:08 - mmengine - INFO - Epoch(train)   [2][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:52  time: 0.0735  data_time: 0.0376  loss: 1.0766  loss_disc_fake: 0.6054  loss_disc_real: 0.3645  loss_gen: 1.0766
# 04/22 05:32:08 - mmengine - INFO - Epoch(train)   [2][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:46  time: 0.0710  data_time: 0.0366  loss: 1.0504  loss_disc_fake: 0.6332  loss_disc_real: 0.3640  loss_gen: 1.0504
# 04/22 05:32:09 - mmengine - INFO - Epoch(train)   [2][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:55  time: 0.0835  data_time: 0.0441  loss: 1.0594  loss_disc_fake: 0.6406  loss_disc_real: 0.3598  loss_gen: 1.0594
# 04/22 05:32:10 - mmengine - INFO - Epoch(train)   [2][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:56  time: 0.0765  data_time: 0.0402  loss: 1.1086  loss_disc_fake: 0.6285  loss_disc_real: 0.3434  loss_gen: 1.1086
# 04/22 05:32:10 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:32:10 - mmengine - INFO - Saving checkpoint at 2 epochs
# 04/22 05:32:11 - mmengine - INFO - Epoch(train)   [3][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:48  time: 0.0782  data_time: 0.0424  loss: 1.0274  loss_disc_fake: 0.6755  loss_disc_real: 0.3117  loss_gen: 1.0274
# 04/22 05:32:12 - mmengine - INFO - Epoch(train)   [3][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:45  time: 0.0730  data_time: 0.0372  loss: 0.9876  loss_disc_fake: 0.6686  loss_disc_real: 0.3063  loss_gen: 0.9876
# 04/22 05:32:13 - mmengine - INFO - Epoch(train)   [3][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:36  time: 0.0659  data_time: 0.0323  loss: 1.0080  loss_disc_fake: 0.6454  loss_disc_real: 0.2893  loss_gen: 1.0080
# 04/22 05:32:13 - mmengine - INFO - Epoch(train)   [3][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:24  time: 0.0632  data_time: 0.0301  loss: 0.9969  loss_disc_fake: 0.6257  loss_disc_real: 0.2922  loss_gen: 0.9969
# 04/22 05:32:14 - mmengine - INFO - Epoch(train)   [3][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:19  time: 0.0706  data_time: 0.0347  loss: 1.0174  loss_disc_fake: 0.6867  loss_disc_real: 0.3335  loss_gen: 1.0174
# 04/22 05:32:15 - mmengine - INFO - Epoch(train)   [3][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:18  time: 0.0730  data_time: 0.0351  loss: 1.0785  loss_disc_fake: 0.6453  loss_disc_real: 0.3121  loss_gen: 1.0785
# 04/22 05:32:15 - mmengine - INFO - Epoch(train)   [3][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:12  time: 0.0694  data_time: 0.0340  loss: 1.1379  loss_disc_fake: 0.6494  loss_disc_real: 0.3306  loss_gen: 1.1379
# 04/22 05:32:16 - mmengine - INFO - Epoch(train)   [3][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:42:09  time: 0.0709  data_time: 0.0365  loss: 1.0631  loss_disc_fake: 0.6873  loss_disc_real: 0.3817  loss_gen: 1.0631
# 04/22 05:32:17 - mmengine - INFO - Epoch(train)   [3][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:58  time: 0.0618  data_time: 0.0286  loss: 1.1624  loss_disc_fake: 0.5866  loss_disc_real: 0.3184  loss_gen: 1.1624
# 04/22 05:32:17 - mmengine - INFO - Epoch(train)   [3][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:52  time: 0.0672  data_time: 0.0331  loss: 1.1592  loss_disc_fake: 0.5992  loss_disc_real: 0.3940  loss_gen: 1.1592
# 04/22 05:32:18 - mmengine - INFO - Epoch(train)   [3][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:51  time: 0.0739  data_time: 0.0388  loss: 1.2033  loss_disc_fake: 0.6433  loss_disc_real: 0.4088  loss_gen: 1.2033
# 04/22 05:32:19 - mmengine - INFO - Epoch(train)   [3][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:51  time: 0.0750  data_time: 0.0382  loss: 1.2098  loss_disc_fake: 0.6759  loss_disc_real: 0.3790  loss_gen: 1.2098
# 04/22 05:32:19 - mmengine - INFO - Epoch(train)   [3][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:45  time: 0.0663  data_time: 0.0321  loss: 1.2358  loss_disc_fake: 0.6212  loss_disc_real: 0.4104  loss_gen: 1.2358
# 04/22 05:32:20 - mmengine - INFO - Epoch(train)   [3][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:39  time: 0.0669  data_time: 0.0327  loss: 1.2148  loss_disc_fake: 0.6683  loss_disc_real: 0.4527  loss_gen: 1.2148
# 04/22 05:32:21 - mmengine - INFO - Epoch(train)   [3][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:37  time: 0.0715  data_time: 0.0374  loss: 1.2197  loss_disc_fake: 0.6217  loss_disc_real: 0.4196  loss_gen: 1.2197
# 04/22 05:32:21 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:32:21 - mmengine - INFO - Saving checkpoint at 3 epochs
# 04/22 05:32:22 - mmengine - INFO - Epoch(train)   [4][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:30  time: 0.0729  data_time: 0.0375  loss: 1.2292  loss_disc_fake: 0.6233  loss_disc_real: 0.4350  loss_gen: 1.2292
# 04/22 05:32:23 - mmengine - INFO - Epoch(train)   [4][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:25  time: 0.0669  data_time: 0.0297  loss: 1.2749  loss_disc_fake: 0.6540  loss_disc_real: 0.4091  loss_gen: 1.2749
# 04/22 05:32:23 - mmengine - INFO - Epoch(train)   [4][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:22  time: 0.0690  data_time: 0.0302  loss: 1.2287  loss_disc_fake: 0.6420  loss_disc_real: 0.4425  loss_gen: 1.2287
# 04/22 05:32:24 - mmengine - INFO - Epoch(train)   [4][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:21  time: 0.0727  data_time: 0.0345  loss: 1.2481  loss_disc_fake: 0.6163  loss_disc_real: 0.3790  loss_gen: 1.2481
# 04/22 05:32:25 - mmengine - INFO - Epoch(train)   [4][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:23  time: 0.0777  data_time: 0.0339  loss: 1.2941  loss_disc_fake: 0.5785  loss_disc_real: 0.3618  loss_gen: 1.2941
# 04/22 05:32:26 - mmengine - INFO - Epoch(train)   [4][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:26  time: 0.0786  data_time: 0.0367  loss: 1.2876  loss_disc_fake: 0.5692  loss_disc_real: 0.3534  loss_gen: 1.2876
# 04/22 05:32:26 - mmengine - INFO - Epoch(train)   [4][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:22  time: 0.0670  data_time: 0.0328  loss: 1.2318  loss_disc_fake: 0.6669  loss_disc_real: 0.3909  loss_gen: 1.2318
# 04/22 05:32:27 - mmengine - INFO - Epoch(train)   [4][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:20  time: 0.0709  data_time: 0.0355  loss: 1.1437  loss_disc_fake: 0.6203  loss_disc_real: 0.4081  loss_gen: 1.1437
# 04/22 05:32:28 - mmengine - INFO - Epoch(train)   [4][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:18  time: 0.0718  data_time: 0.0352  loss: 1.1526  loss_disc_fake: 0.6597  loss_disc_real: 0.4143  loss_gen: 1.1526
# 04/22 05:32:28 - mmengine - INFO - Epoch(train)   [4][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:12  time: 0.0636  data_time: 0.0299  loss: 1.1874  loss_disc_fake: 0.6060  loss_disc_real: 0.3811  loss_gen: 1.1874
# 04/22 05:32:29 - mmengine - INFO - Epoch(train)   [4][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:08  time: 0.0674  data_time: 0.0338  loss: 1.1728  loss_disc_fake: 0.5814  loss_disc_real: 0.3862  loss_gen: 1.1728
# 04/22 05:32:30 - mmengine - INFO - Epoch(train)   [4][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:03  time: 0.0661  data_time: 0.0319  loss: 1.1059  loss_disc_fake: 0.6009  loss_disc_real: 0.3951  loss_gen: 1.1059
# 04/22 05:32:31 - mmengine - INFO - Epoch(train)   [4][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:01  time: 0.0697  data_time: 0.0359  loss: 1.1542  loss_disc_fake: 0.6470  loss_disc_real: 0.4091  loss_gen: 1.1542
# 04/22 05:32:31 - mmengine - INFO - Epoch(train)   [4][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:01  time: 0.0729  data_time: 0.0355  loss: 1.0496  loss_disc_fake: 0.6021  loss_disc_real: 0.4380  loss_gen: 1.0496
# 04/22 05:32:32 - mmengine - INFO - Epoch(train)   [4][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:02  time: 0.0764  data_time: 0.0402  loss: 1.1317  loss_disc_fake: 0.6376  loss_disc_real: 0.4264  loss_gen: 1.1317
# 04/22 05:32:32 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:32:32 - mmengine - INFO - Saving checkpoint at 4 epochs
# 04/22 05:32:33 - mmengine - INFO - Epoch(train)   [5][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:04  time: 0.0832  data_time: 0.0464  loss: 1.1961  loss_disc_fake: 0.6575  loss_disc_real: 0.4641  loss_gen: 1.1961
# 04/22 05:32:34 - mmengine - INFO - Epoch(train)   [5][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:02  time: 0.0706  data_time: 0.0357  loss: 1.1585  loss_disc_fake: 0.6074  loss_disc_real: 0.4962  loss_gen: 1.1585
# 04/22 05:32:35 - mmengine - INFO - Epoch(train)   [5][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:01  time: 0.0710  data_time: 0.0351  loss: 1.1566  loss_disc_fake: 0.5808  loss_disc_real: 0.4990  loss_gen: 1.1566
# 04/22 05:32:36 - mmengine - INFO - Epoch(train)   [5][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:02  time: 0.0774  data_time: 0.0422  loss: 1.1613  loss_disc_fake: 0.6203  loss_disc_real: 0.5042  loss_gen: 1.1613
# 04/22 05:32:36 - mmengine - INFO - Epoch(train)   [5][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:41:00  time: 0.0698  data_time: 0.0358  loss: 1.1980  loss_disc_fake: 0.5647  loss_disc_real: 0.4724  loss_gen: 1.1980
# 04/22 05:32:37 - mmengine - INFO - Epoch(train)   [5][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:58  time: 0.0693  data_time: 0.0335  loss: 1.1434  loss_disc_fake: 0.6223  loss_disc_real: 0.5294  loss_gen: 1.1434
# 04/22 05:32:38 - mmengine - INFO - Epoch(train)   [5][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:57  time: 0.0719  data_time: 0.0327  loss: 1.1506  loss_disc_fake: 0.6361  loss_disc_real: 0.4870  loss_gen: 1.1506
# 04/22 05:32:38 - mmengine - INFO - Epoch(train)   [5][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:55  time: 0.0709  data_time: 0.0342  loss: 1.2556  loss_disc_fake: 0.6044  loss_disc_real: 0.4558  loss_gen: 1.2556
# 04/22 05:32:39 - mmengine - INFO - Epoch(train)   [5][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:52  time: 0.0677  data_time: 0.0330  loss: 1.1768  loss_disc_fake: 0.5970  loss_disc_real: 0.5204  loss_gen: 1.1768
# 04/22 05:32:40 - mmengine - INFO - Epoch(train)   [5][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:48  time: 0.0657  data_time: 0.0313  loss: 1.2018  loss_disc_fake: 0.6337  loss_disc_real: 0.5067  loss_gen: 1.2018
# 04/22 05:32:40 - mmengine - INFO - Epoch(train)   [5][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:45  time: 0.0679  data_time: 0.0335  loss: 1.1889  loss_disc_fake: 0.5698  loss_disc_real: 0.4689  loss_gen: 1.1889
# 04/22 05:32:41 - mmengine - INFO - Epoch(train)   [5][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:44  time: 0.0713  data_time: 0.0355  loss: 1.2258  loss_disc_fake: 0.5359  loss_disc_real: 0.4365  loss_gen: 1.2258
# 04/22 05:32:42 - mmengine - INFO - Epoch(train)   [5][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:40  time: 0.0650  data_time: 0.0305  loss: 1.2427  loss_disc_fake: 0.5363  loss_disc_real: 0.4333  loss_gen: 1.2427
# 04/22 05:32:42 - mmengine - INFO - Epoch(train)   [5][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:36  time: 0.0637  data_time: 0.0293  loss: 1.2856  loss_disc_fake: 0.5614  loss_disc_real: 0.4514  loss_gen: 1.2856
# 04/22 05:32:43 - mmengine - INFO - Epoch(train)   [5][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:32  time: 0.0649  data_time: 0.0310  loss: 1.3385  loss_disc_fake: 0.5480  loss_disc_real: 0.4592  loss_gen: 1.3385
# 04/22 05:32:43 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:32:43 - mmengine - INFO - Saving checkpoint at 5 epochs
# 04/22 05:32:44 - mmengine - INFO - Epoch(train)   [6][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:27  time: 0.0721  data_time: 0.0375  loss: 1.3238  loss_disc_fake: 0.5108  loss_disc_real: 0.4544  loss_gen: 1.3238
# 04/22 05:32:45 - mmengine - INFO - Epoch(train)   [6][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:26  time: 0.0707  data_time: 0.0358  loss: 1.3333  loss_disc_fake: 0.5483  loss_disc_real: 0.5398  loss_gen: 1.3333
# 04/22 05:32:46 - mmengine - INFO - Epoch(train)   [6][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:23  time: 0.0680  data_time: 0.0335  loss: 1.2998  loss_disc_fake: 0.5298  loss_disc_real: 0.4880  loss_gen: 1.2998
# 04/22 05:32:46 - mmengine - INFO - Epoch(train)   [6][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:21  time: 0.0691  data_time: 0.0342  loss: 1.3612  loss_disc_fake: 0.5942  loss_disc_real: 0.5136  loss_gen: 1.3612
# 04/22 05:32:47 - mmengine - INFO - Epoch(train)   [6][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:18  time: 0.0654  data_time: 0.0289  loss: 1.3208  loss_disc_fake: 0.5424  loss_disc_real: 0.4289  loss_gen: 1.3208
# 04/22 05:32:48 - mmengine - INFO - Epoch(train)   [6][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:17  time: 0.0713  data_time: 0.0344  loss: 1.2972  loss_disc_fake: 0.5423  loss_disc_real: 0.4773  loss_gen: 1.2972
# 04/22 05:32:48 - mmengine - INFO - Epoch(train)   [6][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:17  time: 0.0741  data_time: 0.0396  loss: 1.3615  loss_disc_fake: 0.5167  loss_disc_real: 0.4466  loss_gen: 1.3615
# 04/22 05:32:49 - mmengine - INFO - Epoch(train)   [6][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:17  time: 0.0719  data_time: 0.0367  loss: 1.3754  loss_disc_fake: 0.4956  loss_disc_real: 0.4401  loss_gen: 1.3754
# 04/22 05:32:50 - mmengine - INFO - Epoch(train)   [6][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:15  time: 0.0701  data_time: 0.0352  loss: 1.3705  loss_disc_fake: 0.5198  loss_disc_real: 0.4243  loss_gen: 1.3705
# 04/22 05:32:51 - mmengine - INFO - Epoch(train)   [6][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:12  time: 0.0646  data_time: 0.0295  loss: 1.3135  loss_disc_fake: 0.4932  loss_disc_real: 0.4268  loss_gen: 1.3135
# 04/22 05:32:51 - mmengine - INFO - Epoch(train)   [6][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:08  time: 0.0632  data_time: 0.0293  loss: 1.3411  loss_disc_fake: 0.4986  loss_disc_real: 0.4380  loss_gen: 1.3411
# 04/22 05:32:52 - mmengine - INFO - Epoch(train)   [6][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:05  time: 0.0669  data_time: 0.0334  loss: 1.4072  loss_disc_fake: 0.4836  loss_disc_real: 0.3955  loss_gen: 1.4072
# 04/22 05:32:52 - mmengine - INFO - Epoch(train)   [6][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:01  time: 0.0615  data_time: 0.0280  loss: 1.4052  loss_disc_fake: 0.4761  loss_disc_real: 0.3903  loss_gen: 1.4052
# 04/22 05:32:53 - mmengine - INFO - Epoch(train)   [6][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:59  time: 0.0663  data_time: 0.0302  loss: 1.4534  loss_disc_fake: 0.5410  loss_disc_real: 0.4089  loss_gen: 1.4534
# 04/22 05:32:54 - mmengine - INFO - Epoch(train)   [6][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:54  time: 0.0621  data_time: 0.0283  loss: 1.3709  loss_disc_fake: 0.4759  loss_disc_real: 0.4086  loss_gen: 1.3709
# 04/22 05:32:54 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:32:54 - mmengine - INFO - Saving checkpoint at 6 epochs
# 04/22 05:32:55 - mmengine - INFO - Epoch(train)   [7][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:00  time: 0.1013  data_time: 0.0646  loss: 1.2803  loss_disc_fake: 0.5117  loss_disc_real: 0.4009  loss_gen: 1.2803
# 04/22 05:32:56 - mmengine - INFO - Epoch(train)   [7][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:02  time: 0.0770  data_time: 0.0411  loss: 1.3000  loss_disc_fake: 0.5702  loss_disc_real: 0.3959  loss_gen: 1.3000
# 04/22 05:32:57 - mmengine - INFO - Epoch(train)   [7][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:04  time: 0.0808  data_time: 0.0393  loss: 1.2795  loss_disc_fake: 0.5580  loss_disc_real: 0.3990  loss_gen: 1.2795
# 04/22 05:32:58 - mmengine - INFO - Epoch(train)   [7][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:07  time: 0.0819  data_time: 0.0379  loss: 1.2596  loss_disc_fake: 0.5435  loss_disc_real: 0.4017  loss_gen: 1.2596
# 04/22 05:32:58 - mmengine - INFO - Epoch(train)   [7][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:07  time: 0.0728  data_time: 0.0347  loss: 1.2671  loss_disc_fake: 0.5421  loss_disc_real: 0.4125  loss_gen: 1.2671
# 04/22 05:32:59 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:32:59 - mmengine - INFO - Epoch(train)   [7][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:07  time: 0.0744  data_time: 0.0388  loss: 1.4160  loss_disc_fake: 0.5011  loss_disc_real: 0.3787  loss_gen: 1.4160
# 04/22 05:33:00 - mmengine - INFO - Epoch(train)   [7][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:06  time: 0.0723  data_time: 0.0355  loss: 1.4356  loss_disc_fake: 0.5045  loss_disc_real: 0.4078  loss_gen: 1.4356
# 04/22 05:33:01 - mmengine - INFO - Epoch(train)   [7][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:13  time: 0.0942  data_time: 0.0577  loss: 1.2711  loss_disc_fake: 0.5993  loss_disc_real: 0.5093  loss_gen: 1.2711
# 04/22 05:33:01 - mmengine - INFO - Epoch(train)   [7][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:11  time: 0.0691  data_time: 0.0357  loss: 1.3251  loss_disc_fake: 0.5699  loss_disc_real: 0.4562  loss_gen: 1.3251
# 04/22 05:33:02 - mmengine - INFO - Epoch(train)   [7][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:11  time: 0.0743  data_time: 0.0388  loss: 1.2747  loss_disc_fake: 0.4999  loss_disc_real: 0.4268  loss_gen: 1.2747
# 04/22 05:33:03 - mmengine - INFO - Epoch(train)   [7][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:10  time: 0.0693  data_time: 0.0345  loss: 1.4082  loss_disc_fake: 0.4976  loss_disc_real: 0.3993  loss_gen: 1.4082
# 04/22 05:33:04 - mmengine - INFO - Epoch(train)   [7][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:13  time: 0.0857  data_time: 0.0475  loss: 1.4255  loss_disc_fake: 0.5333  loss_disc_real: 0.4239  loss_gen: 1.4255
# 04/22 05:33:04 - mmengine - INFO - Epoch(train)   [7][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:11  time: 0.0674  data_time: 0.0316  loss: 1.4087  loss_disc_fake: 0.4658  loss_disc_real: 0.4237  loss_gen: 1.4087
# 04/22 05:33:05 - mmengine - INFO - Epoch(train)   [7][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:12  time: 0.0773  data_time: 0.0415  loss: 1.4597  loss_disc_fake: 0.4897  loss_disc_real: 0.4070  loss_gen: 1.4597
# 04/22 05:33:06 - mmengine - INFO - Epoch(train)   [7][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:09  time: 0.0655  data_time: 0.0314  loss: 1.4062  loss_disc_fake: 0.5588  loss_disc_real: 0.5183  loss_gen: 1.4062
# 04/22 05:33:06 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:33:06 - mmengine - INFO - Saving checkpoint at 7 epochs
# 04/22 05:33:07 - mmengine - INFO - Epoch(train)   [8][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:06  time: 0.0769  data_time: 0.0406  loss: 1.4097  loss_disc_fake: 0.5210  loss_disc_real: 0.4515  loss_gen: 1.4097
# 04/22 05:33:08 - mmengine - INFO - Epoch(train)   [8][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:04  time: 0.0697  data_time: 0.0336  loss: 1.4005  loss_disc_fake: 0.4832  loss_disc_real: 0.4861  loss_gen: 1.4005
# 04/22 05:33:08 - mmengine - INFO - Epoch(train)   [8][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:03  time: 0.0711  data_time: 0.0370  loss: 1.4716  loss_disc_fake: 0.5490  loss_disc_real: 0.4826  loss_gen: 1.4716
# 04/22 05:33:09 - mmengine - INFO - Epoch(train)   [8][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:02  time: 0.0710  data_time: 0.0362  loss: 1.3604  loss_disc_fake: 0.5346  loss_disc_real: 0.5070  loss_gen: 1.3604
# 04/22 05:33:10 - mmengine - INFO - Epoch(train)   [8][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:02  time: 0.0737  data_time: 0.0370  loss: 1.4564  loss_disc_fake: 0.4905  loss_disc_real: 0.4613  loss_gen: 1.4564
# 04/22 05:33:11 - mmengine - INFO - Epoch(train)   [8][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:40:02  time: 0.0731  data_time: 0.0389  loss: 1.3972  loss_disc_fake: 0.4391  loss_disc_real: 0.4371  loss_gen: 1.3972
# 04/22 05:33:11 - mmengine - INFO - Epoch(train)   [8][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:59  time: 0.0668  data_time: 0.0328  loss: 1.4421  loss_disc_fake: 0.6116  loss_disc_real: 0.5515  loss_gen: 1.4421
# 04/22 05:33:12 - mmengine - INFO - Epoch(train)   [8][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:57  time: 0.0661  data_time: 0.0314  loss: 1.3938  loss_disc_fake: 0.5354  loss_disc_real: 0.4846  loss_gen: 1.3938
# 04/22 05:33:13 - mmengine - INFO - Epoch(train)   [8][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:54  time: 0.0627  data_time: 0.0290  loss: 1.3079  loss_disc_fake: 0.4816  loss_disc_real: 0.5121  loss_gen: 1.3079
# 04/22 05:33:13 - mmengine - INFO - Epoch(train)   [8][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:53  time: 0.0725  data_time: 0.0371  loss: 1.3979  loss_disc_fake: 0.4799  loss_disc_real: 0.4600  loss_gen: 1.3979
# 04/22 05:33:14 - mmengine - INFO - Epoch(train)   [8][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:56  time: 0.0832  data_time: 0.0457  loss: 1.4807  loss_disc_fake: 0.4250  loss_disc_real: 0.4153  loss_gen: 1.4807
# 04/22 05:33:15 - mmengine - INFO - Epoch(train)   [8][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:55  time: 0.0719  data_time: 0.0371  loss: 1.5844  loss_disc_fake: 0.4212  loss_disc_real: 0.3854  loss_gen: 1.5844
# 04/22 05:33:16 - mmengine - INFO - Epoch(train)   [8][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:54  time: 0.0710  data_time: 0.0350  loss: 1.5164  loss_disc_fake: 0.3840  loss_disc_real: 0.3809  loss_gen: 1.5164
# 04/22 05:33:16 - mmengine - INFO - Epoch(train)   [8][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:52  time: 0.0660  data_time: 0.0318  loss: 1.5778  loss_disc_fake: 0.5241  loss_disc_real: 0.5214  loss_gen: 1.5778
# 04/22 05:33:17 - mmengine - INFO - Epoch(train)   [8][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:50  time: 0.0673  data_time: 0.0311  loss: 1.5317  loss_disc_fake: 0.4332  loss_disc_real: 0.3878  loss_gen: 1.5317
# 04/22 05:33:17 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:33:17 - mmengine - INFO - Saving checkpoint at 8 epochs
# 04/22 05:33:18 - mmengine - INFO - Epoch(train)   [9][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:49  time: 0.0838  data_time: 0.0494  loss: 1.6347  loss_disc_fake: 0.4353  loss_disc_real: 0.4115  loss_gen: 1.6347
# 04/22 05:33:19 - mmengine - INFO - Epoch(train)   [9][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:49  time: 0.0723  data_time: 0.0368  loss: 1.5656  loss_disc_fake: 0.4018  loss_disc_real: 0.4117  loss_gen: 1.5656
# 04/22 05:33:20 - mmengine - INFO - Epoch(train)   [9][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:49  time: 0.0761  data_time: 0.0401  loss: 1.6179  loss_disc_fake: 0.4976  loss_disc_real: 0.4208  loss_gen: 1.6179
# 04/22 05:33:20 - mmengine - INFO - Epoch(train)   [9][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:48  time: 0.0707  data_time: 0.0364  loss: 1.5117  loss_disc_fake: 0.5278  loss_disc_real: 0.4878  loss_gen: 1.5117
# 04/22 05:33:21 - mmengine - INFO - Epoch(train)   [9][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:46  time: 0.0683  data_time: 0.0336  loss: 1.4939  loss_disc_fake: 0.4620  loss_disc_real: 0.4837  loss_gen: 1.4939
# 04/22 05:33:22 - mmengine - INFO - Epoch(train)   [9][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:45  time: 0.0702  data_time: 0.0358  loss: 1.4967  loss_disc_fake: 0.4324  loss_disc_real: 0.4147  loss_gen: 1.4967
# 04/22 05:33:22 - mmengine - INFO - Epoch(train)   [9][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:43  time: 0.0669  data_time: 0.0326  loss: 1.5610  loss_disc_fake: 0.4307  loss_disc_real: 0.3956  loss_gen: 1.5610
# 04/22 05:33:23 - mmengine - INFO - Epoch(train)   [9][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:42  time: 0.0694  data_time: 0.0346  loss: 1.5276  loss_disc_fake: 0.4747  loss_disc_real: 0.4349  loss_gen: 1.5276
# 04/22 05:33:24 - mmengine - INFO - Epoch(train)   [9][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:40  time: 0.0662  data_time: 0.0317  loss: 1.4524  loss_disc_fake: 0.4629  loss_disc_real: 0.4814  loss_gen: 1.4524
# 04/22 05:33:25 - mmengine - INFO - Epoch(train)   [9][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:38  time: 0.0682  data_time: 0.0347  loss: 1.3892  loss_disc_fake: 0.4439  loss_disc_real: 0.5218  loss_gen: 1.3892
# 04/22 05:33:25 - mmengine - INFO - Epoch(train)   [9][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:37  time: 0.0706  data_time: 0.0366  loss: 1.5921  loss_disc_fake: 0.5167  loss_disc_real: 0.4586  loss_gen: 1.5921
# 04/22 05:33:26 - mmengine - INFO - Epoch(train)   [9][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:36  time: 0.0682  data_time: 0.0334  loss: 1.5464  loss_disc_fake: 0.5024  loss_disc_real: 0.4622  loss_gen: 1.5464
# 04/22 05:33:27 - mmengine - INFO - Epoch(train)   [9][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:32  time: 0.0601  data_time: 0.0265  loss: 1.5328  loss_disc_fake: 0.3755  loss_disc_real: 0.4436  loss_gen: 1.5328
# 04/22 05:33:27 - mmengine - INFO - Epoch(train)   [9][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:31  time: 0.0669  data_time: 0.0321  loss: 1.5900  loss_disc_fake: 0.4436  loss_disc_real: 0.4344  loss_gen: 1.5900
# 04/22 05:33:28 - mmengine - INFO - Epoch(train)   [9][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:30  time: 0.0704  data_time: 0.0338  loss: 1.5970  loss_disc_fake: 0.4363  loss_disc_real: 0.4307  loss_gen: 1.5970
# 04/22 05:33:28 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:33:28 - mmengine - INFO - Saving checkpoint at 9 epochs
# 04/22 05:33:29 - mmengine - INFO - Epoch(train)  [10][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:31  time: 0.0856  data_time: 0.0448  loss: 1.6890  loss_disc_fake: 0.4691  loss_disc_real: 0.4881  loss_gen: 1.6890
# 04/22 05:33:30 - mmengine - INFO - Epoch(train)  [10][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:31  time: 0.0746  data_time: 0.0363  loss: 1.4470  loss_disc_fake: 0.4825  loss_disc_real: 0.4683  loss_gen: 1.4470
# 04/22 05:33:31 - mmengine - INFO - Epoch(train)  [10][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:29  time: 0.0665  data_time: 0.0325  loss: 1.5806  loss_disc_fake: 0.4869  loss_disc_real: 0.4566  loss_gen: 1.5806
# 04/22 05:33:31 - mmengine - INFO - Epoch(train)  [10][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:26  time: 0.0643  data_time: 0.0302  loss: 1.5504  loss_disc_fake: 0.4226  loss_disc_real: 0.4217  loss_gen: 1.5504
# 04/22 05:33:32 - mmengine - INFO - Epoch(train)  [10][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:25  time: 0.0678  data_time: 0.0321  loss: 1.6196  loss_disc_fake: 0.4213  loss_disc_real: 0.3792  loss_gen: 1.6196
# 04/22 05:33:33 - mmengine - INFO - Epoch(train)  [10][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:25  time: 0.0767  data_time: 0.0412  loss: 1.6246  loss_disc_fake: 0.4362  loss_disc_real: 0.4033  loss_gen: 1.6246
# 04/22 05:33:34 - mmengine - INFO - Epoch(train)  [10][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:25  time: 0.0752  data_time: 0.0403  loss: 1.5867  loss_disc_fake: 0.4906  loss_disc_real: 0.4569  loss_gen: 1.5867
# 04/22 05:33:34 - mmengine - INFO - Epoch(train)  [10][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:24  time: 0.0675  data_time: 0.0327  loss: 1.4908  loss_disc_fake: 0.4144  loss_disc_real: 0.4047  loss_gen: 1.4908
# 04/22 05:33:35 - mmengine - INFO - Epoch(train)  [10][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:22  time: 0.0678  data_time: 0.0341  loss: 1.6396  loss_disc_fake: 0.4629  loss_disc_real: 0.4030  loss_gen: 1.6396
# 04/22 05:33:36 - mmengine - INFO - Epoch(train)  [10][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:22  time: 0.0733  data_time: 0.0384  loss: 1.6446  loss_disc_fake: 0.4527  loss_disc_real: 0.4360  loss_gen: 1.6446
# 04/22 05:33:36 - mmengine - INFO - Epoch(train)  [10][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:21  time: 0.0726  data_time: 0.0379  loss: 1.5567  loss_disc_fake: 0.3862  loss_disc_real: 0.3744  loss_gen: 1.5567
# 04/22 05:33:37 - mmengine - INFO - Epoch(train)  [10][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:19  time: 0.0654  data_time: 0.0304  loss: 1.6323  loss_disc_fake: 0.4857  loss_disc_real: 0.4454  loss_gen: 1.6323
# 04/22 05:33:38 - mmengine - INFO - Epoch(train)  [10][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:19  time: 0.0722  data_time: 0.0351  loss: 1.5761  loss_disc_fake: 0.5141  loss_disc_real: 0.4988  loss_gen: 1.5761
# 04/22 05:33:38 - mmengine - INFO - Epoch(train)  [10][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:18  time: 0.0729  data_time: 0.0373  loss: 1.4789  loss_disc_fake: 0.4840  loss_disc_real: 0.5559  loss_gen: 1.4789
# 04/22 05:33:39 - mmengine - INFO - Epoch(train)  [10][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:19  time: 0.0799  data_time: 0.0428  loss: 1.4913  loss_disc_fake: 0.4555  loss_disc_real: 0.4525  loss_gen: 1.4913
# 04/22 05:33:40 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:33:40 - mmengine - INFO - Saving checkpoint at 10 epochs
# 04/22 05:33:41 - mmengine - INFO - Epoch(train)  [11][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:18  time: 0.0739  data_time: 0.0391  loss: 1.3943  loss_disc_fake: 0.5125  loss_disc_real: 0.5301  loss_gen: 1.3943
# 04/22 05:33:41 - mmengine - INFO - Epoch(train)  [11][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:17  time: 0.0699  data_time: 0.0337  loss: 1.4001  loss_disc_fake: 0.4890  loss_disc_real: 0.5250  loss_gen: 1.4001
# 04/22 05:33:42 - mmengine - INFO - Epoch(train)  [11][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:15  time: 0.0658  data_time: 0.0315  loss: 1.3332  loss_disc_fake: 0.4764  loss_disc_real: 0.4772  loss_gen: 1.3332
# 04/22 05:33:43 - mmengine - INFO - Epoch(train)  [11][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:13  time: 0.0670  data_time: 0.0332  loss: 1.4798  loss_disc_fake: 0.4459  loss_disc_real: 0.4835  loss_gen: 1.4798
# 04/22 05:33:43 - mmengine - INFO - Epoch(train)  [11][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:12  time: 0.0684  data_time: 0.0342  loss: 1.4185  loss_disc_fake: 0.4128  loss_disc_real: 0.4719  loss_gen: 1.4185
# 04/22 05:33:44 - mmengine - INFO - Epoch(train)  [11][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:12  time: 0.0734  data_time: 0.0393  loss: 1.6502  loss_disc_fake: 0.4695  loss_disc_real: 0.4332  loss_gen: 1.6502
# 04/22 05:33:45 - mmengine - INFO - Epoch(train)  [11][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:11  time: 0.0714  data_time: 0.0355  loss: 1.6285  loss_disc_fake: 0.4269  loss_disc_real: 0.4178  loss_gen: 1.6285
# 04/22 05:33:45 - mmengine - INFO - Epoch(train)  [11][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:10  time: 0.0706  data_time: 0.0322  loss: 1.5164  loss_disc_fake: 0.4401  loss_disc_real: 0.4562  loss_gen: 1.5164
# 04/22 05:33:46 - mmengine - INFO - Epoch(train)  [11][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:10  time: 0.0740  data_time: 0.0393  loss: 1.5588  loss_disc_fake: 0.5063  loss_disc_real: 0.5228  loss_gen: 1.5588
# 04/22 05:33:47 - mmengine - INFO - Epoch(train)  [11][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:08  time: 0.0688  data_time: 0.0339  loss: 1.3919  loss_disc_fake: 0.4765  loss_disc_real: 0.5081  loss_gen: 1.3919
# 04/22 05:33:48 - mmengine - INFO - Epoch(train)  [11][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:07  time: 0.0697  data_time: 0.0339  loss: 1.5389  loss_disc_fake: 0.4558  loss_disc_real: 0.4390  loss_gen: 1.5389
# 04/22 05:33:48 - mmengine - INFO - Epoch(train)  [11][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:07  time: 0.0739  data_time: 0.0394  loss: 1.5014  loss_disc_fake: 0.3937  loss_disc_real: 0.4293  loss_gen: 1.5014
# 04/22 05:33:49 - mmengine - INFO - Epoch(train)  [11][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:07  time: 0.0719  data_time: 0.0364  loss: 1.5288  loss_disc_fake: 0.4474  loss_disc_real: 0.4510  loss_gen: 1.5288
# 04/22 05:33:50 - mmengine - INFO - Epoch(train)  [11][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:04  time: 0.0643  data_time: 0.0303  loss: 1.4494  loss_disc_fake: 0.4593  loss_disc_real: 0.4534  loss_gen: 1.4494
# 04/22 05:33:50 - mmengine - INFO - Epoch(train)  [11][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:39:02  time: 0.0645  data_time: 0.0305  loss: 1.4817  loss_disc_fake: 0.4554  loss_disc_real: 0.4420  loss_gen: 1.4817
# 04/22 05:33:51 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 05:33:51 - mmengine - INFO - Saving checkpoint at 11 epochs
# ...
# 04/22 06:12:52 - mmengine - INFO - Epoch(train) [217][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:42  time: 0.0721  data_time: 0.0362  loss: 1.3883  loss_disc_fake: 0.4334  loss_disc_real: 0.4810  loss_gen: 1.3883
# 04/22 06:12:53 - mmengine - INFO - Epoch(train) [217][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:41  time: 0.0715  data_time: 0.0353  loss: 1.3842  loss_disc_fake: 0.4453  loss_disc_real: 0.4984  loss_gen: 1.3842
# 04/22 06:12:54 - mmengine - INFO - Epoch(train) [217][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:40  time: 0.0717  data_time: 0.0350  loss: 1.4244  loss_disc_fake: 0.4353  loss_disc_real: 0.5240  loss_gen: 1.4244
# 04/22 06:12:54 - mmengine - INFO - Epoch(train) [217][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:40  time: 0.0653  data_time: 0.0306  loss: 1.4346  loss_disc_fake: 0.4259  loss_disc_real: 0.4507  loss_gen: 1.4346
# 04/22 06:12:55 - mmengine - INFO - Epoch(train) [217][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:39  time: 0.0677  data_time: 0.0327  loss: 1.3153  loss_disc_fake: 0.3864  loss_disc_real: 0.4635  loss_gen: 1.3153
# 04/22 06:12:56 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 06:12:56 - mmengine - INFO - Epoch(train) [217][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:38  time: 0.0691  data_time: 0.0342  loss: 1.4667  loss_disc_fake: 0.4705  loss_disc_real: 0.5062  loss_gen: 1.4667
# 04/22 06:12:56 - mmengine - INFO - Epoch(train) [217][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:37  time: 0.0741  data_time: 0.0361  loss: 1.4196  loss_disc_fake: 0.4473  loss_disc_real: 0.5393  loss_gen: 1.4196
# 04/22 06:12:57 - mmengine - INFO - Epoch(train) [217][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:37  time: 0.0704  data_time: 0.0343  loss: 1.3154  loss_disc_fake: 0.4134  loss_disc_real: 0.4975  loss_gen: 1.3154
# 04/22 06:12:58 - mmengine - INFO - Epoch(train) [217][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:36  time: 0.0741  data_time: 0.0360  loss: 1.5085  loss_disc_fake: 0.4611  loss_disc_real: 0.4832  loss_gen: 1.5085
# 04/22 06:12:59 - mmengine - INFO - Epoch(train) [217][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:35  time: 0.0726  data_time: 0.0369  loss: 1.3831  loss_disc_fake: 0.4429  loss_disc_real: 0.4769  loss_gen: 1.3831
# 04/22 06:12:59 - mmengine - INFO - Epoch(train) [217][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:35  time: 0.0752  data_time: 0.0382  loss: 1.4151  loss_disc_fake: 0.4252  loss_disc_real: 0.5120  loss_gen: 1.4151
# 04/22 06:13:00 - mmengine - INFO - Epoch(train) [217][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:34  time: 0.0689  data_time: 0.0327  loss: 1.4750  loss_disc_fake: 0.4057  loss_disc_real: 0.4599  loss_gen: 1.4750
# 04/22 06:13:00 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 06:13:01 - mmengine - INFO - Saving checkpoint at 217 epochs
# 04/22 06:13:01 - mmengine - INFO - Epoch(train) [218][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:33  time: 0.0708  data_time: 0.0358  loss: 1.5227  loss_disc_fake: 0.4545  loss_disc_real: 0.5288  loss_gen: 1.5227
# 04/22 06:13:02 - mmengine - INFO - Epoch(train) [218][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:32  time: 0.0744  data_time: 0.0361  loss: 1.5207  loss_disc_fake: 0.4098  loss_disc_real: 0.4651  loss_gen: 1.5207
# 04/22 06:13:03 - mmengine - INFO - Epoch(train) [218][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:31  time: 0.0836  data_time: 0.0460  loss: 1.6085  loss_disc_fake: 0.4534  loss_disc_real: 0.4491  loss_gen: 1.6085
# 04/22 06:13:04 - mmengine - INFO - Epoch(train) [218][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:30  time: 0.0868  data_time: 0.0491  loss: 1.4765  loss_disc_fake: 0.4037  loss_disc_real: 0.5001  loss_gen: 1.4765
# 04/22 06:13:05 - mmengine - INFO - Epoch(train) [218][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:30  time: 0.0748  data_time: 0.0389  loss: 1.5019  loss_disc_fake: 0.4148  loss_disc_real: 0.5300  loss_gen: 1.5019
# 04/22 06:13:05 - mmengine - INFO - Epoch(train) [218][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:29  time: 0.0838  data_time: 0.0462  loss: 1.5410  loss_disc_fake: 0.4408  loss_disc_real: 0.4510  loss_gen: 1.5410
# 04/22 06:13:06 - mmengine - INFO - Epoch(train) [218][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:28  time: 0.0775  data_time: 0.0408  loss: 1.3952  loss_disc_fake: 0.4145  loss_disc_real: 0.4896  loss_gen: 1.3952
# 04/22 06:13:07 - mmengine - INFO - Epoch(train) [218][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:28  time: 0.0715  data_time: 0.0363  loss: 1.5211  loss_disc_fake: 0.5121  loss_disc_real: 0.5710  loss_gen: 1.5211
# 04/22 06:13:08 - mmengine - INFO - Epoch(train) [218][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:27  time: 0.0760  data_time: 0.0388  loss: 1.4569  loss_disc_fake: 0.4323  loss_disc_real: 0.4329  loss_gen: 1.4569
# 04/22 06:13:09 - mmengine - INFO - Epoch(train) [218][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:26  time: 0.0789  data_time: 0.0412  loss: 1.4105  loss_disc_fake: 0.3572  loss_disc_real: 0.4715  loss_gen: 1.4105
# 04/22 06:13:09 - mmengine - INFO - Epoch(train) [218][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:25  time: 0.0731  data_time: 0.0379  loss: 1.4967  loss_disc_fake: 0.4237  loss_disc_real: 0.5027  loss_gen: 1.4967
# 04/22 06:13:10 - mmengine - INFO - Epoch(train) [218][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:25  time: 0.0739  data_time: 0.0366  loss: 1.4165  loss_disc_fake: 0.3760  loss_disc_real: 0.4427  loss_gen: 1.4165
# 04/22 06:13:11 - mmengine - INFO - Epoch(train) [218][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:24  time: 0.0876  data_time: 0.0437  loss: 1.4970  loss_disc_fake: 0.4762  loss_disc_real: 0.5466  loss_gen: 1.4970
# 04/22 06:13:12 - mmengine - INFO - Epoch(train) [218][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:23  time: 0.0794  data_time: 0.0386  loss: 1.3636  loss_disc_fake: 0.4093  loss_disc_real: 0.4666  loss_gen: 1.3636
# 04/22 06:13:12 - mmengine - INFO - Epoch(train) [218][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:23  time: 0.0704  data_time: 0.0337  loss: 1.5302  loss_disc_fake: 0.4217  loss_disc_real: 0.4577  loss_gen: 1.5302
# 04/22 06:13:13 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 06:13:13 - mmengine - INFO - Saving checkpoint at 218 epochs
# 04/22 06:13:14 - mmengine - INFO - Epoch(train) [219][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:21  time: 0.0757  data_time: 0.0399  loss: 1.4657  loss_disc_fake: 0.4159  loss_disc_real: 0.4830  loss_gen: 1.4657
# 04/22 06:13:15 - mmengine - INFO - Epoch(train) [219][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:21  time: 0.0745  data_time: 0.0390  loss: 1.4797  loss_disc_fake: 0.4350  loss_disc_real: 0.4747  loss_gen: 1.4797
# 04/22 06:13:15 - mmengine - INFO - Epoch(train) [219][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:20  time: 0.0711  data_time: 0.0340  loss: 1.5417  loss_disc_fake: 0.4787  loss_disc_real: 0.5604  loss_gen: 1.5417
# 04/22 06:13:16 - mmengine - INFO - Epoch(train) [219][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:19  time: 0.0702  data_time: 0.0331  loss: 1.4269  loss_disc_fake: 0.3964  loss_disc_real: 0.4570  loss_gen: 1.4269
# 04/22 06:13:17 - mmengine - INFO - Epoch(train) [219][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:18  time: 0.0597  data_time: 0.0265  loss: 1.4967  loss_disc_fake: 0.4180  loss_disc_real: 0.4661  loss_gen: 1.4967
# 04/22 06:13:17 - mmengine - INFO - Epoch(train) [219][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:18  time: 0.0690  data_time: 0.0342  loss: 1.4537  loss_disc_fake: 0.3873  loss_disc_real: 0.4324  loss_gen: 1.4537
# 04/22 06:13:18 - mmengine - INFO - Epoch(train) [219][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:17  time: 0.0772  data_time: 0.0392  loss: 1.4742  loss_disc_fake: 0.5173  loss_disc_real: 0.6284  loss_gen: 1.4742
# 04/22 06:13:19 - mmengine - INFO - Epoch(train) [219][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:16  time: 0.0774  data_time: 0.0410  loss: 1.5013  loss_disc_fake: 0.4511  loss_disc_real: 0.4733  loss_gen: 1.5013
# 04/22 06:13:19 - mmengine - INFO - Epoch(train) [219][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:16  time: 0.0648  data_time: 0.0304  loss: 1.5034  loss_disc_fake: 0.4267  loss_disc_real: 0.4713  loss_gen: 1.5034
# 04/22 06:13:20 - mmengine - INFO - Epoch(train) [219][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:15  time: 0.0708  data_time: 0.0354  loss: 1.4164  loss_disc_fake: 0.3855  loss_disc_real: 0.4566  loss_gen: 1.4164
# 04/22 06:13:21 - mmengine - INFO - Epoch(train) [219][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:14  time: 0.0763  data_time: 0.0391  loss: 1.5924  loss_disc_fake: 0.4632  loss_disc_real: 0.4768  loss_gen: 1.5924
# 04/22 06:13:22 - mmengine - INFO - Epoch(train) [219][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:13  time: 0.0728  data_time: 0.0353  loss: 1.4587  loss_disc_fake: 0.3937  loss_disc_real: 0.5510  loss_gen: 1.4587
# 04/22 06:13:22 - mmengine - INFO - Epoch(train) [219][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:13  time: 0.0687  data_time: 0.0329  loss: 1.4574  loss_disc_fake: 0.4513  loss_disc_real: 0.4748  loss_gen: 1.4574
# 04/22 06:13:23 - mmengine - INFO - Epoch(train) [219][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:12  time: 0.0690  data_time: 0.0330  loss: 1.5604  loss_disc_fake: 0.4597  loss_disc_real: 0.5642  loss_gen: 1.5604
# 04/22 06:13:24 - mmengine - INFO - Epoch(train) [219][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:11  time: 0.0772  data_time: 0.0416  loss: 1.5054  loss_disc_fake: 0.4662  loss_disc_real: 0.5000  loss_gen: 1.5054
# 04/22 06:13:24 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 06:13:24 - mmengine - INFO - Saving checkpoint at 219 epochs
# 04/22 06:13:25 - mmengine - INFO - Epoch(train) [220][ 10/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:10  time: 0.0804  data_time: 0.0427  loss: 1.4591  loss_disc_fake: 0.4164  loss_disc_real: 0.5264  loss_gen: 1.4591
# 04/22 06:13:26 - mmengine - INFO - Epoch(train) [220][ 20/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:09  time: 0.0704  data_time: 0.0339  loss: 1.4534  loss_disc_fake: 0.4338  loss_disc_real: 0.5321  loss_gen: 1.4534
# 04/22 06:13:27 - mmengine - INFO - Epoch(train) [220][ 30/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:09  time: 0.0672  data_time: 0.0307  loss: 1.5301  loss_disc_fake: 0.4713  loss_disc_real: 0.4699  loss_gen: 1.5301
# 04/22 06:13:27 - mmengine - INFO - Epoch(train) [220][ 40/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:08  time: 0.0726  data_time: 0.0344  loss: 1.4085  loss_disc_fake: 0.4779  loss_disc_real: 0.5222  loss_gen: 1.4085
# 04/22 06:13:28 - mmengine - INFO - Epoch(train) [220][ 50/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:07  time: 0.0685  data_time: 0.0317  loss: 1.4424  loss_disc_fake: 0.4725  loss_disc_real: 0.5289  loss_gen: 1.4424
# 04/22 06:13:29 - mmengine - INFO - Epoch(train) [220][ 60/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:06  time: 0.0678  data_time: 0.0321  loss: 1.4245  loss_disc_fake: 0.4330  loss_disc_real: 0.5215  loss_gen: 1.4245
# 04/22 06:13:29 - mmengine - INFO - Epoch(train) [220][ 70/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:06  time: 0.0742  data_time: 0.0368  loss: 1.5256  loss_disc_fake: 0.3790  loss_disc_real: 0.4964  loss_gen: 1.5256
# 04/22 06:13:30 - mmengine - INFO - Epoch(train) [220][ 80/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:05  time: 0.0736  data_time: 0.0347  loss: 1.5079  loss_disc_fake: 0.4146  loss_disc_real: 0.4427  loss_gen: 1.5079
# 04/22 06:13:31 - mmengine - INFO - Epoch(train) [220][ 90/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:04  time: 0.0668  data_time: 0.0325  loss: 1.4363  loss_disc_fake: 0.4165  loss_disc_real: 0.5049  loss_gen: 1.4363
# 04/22 06:13:31 - mmengine - INFO - Epoch(train) [220][100/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:04  time: 0.0632  data_time: 0.0284  loss: 1.4410  loss_disc_fake: 0.4108  loss_disc_real: 0.4579  loss_gen: 1.4410
# 04/22 06:13:32 - mmengine - INFO - Epoch(train) [220][110/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:03  time: 0.0705  data_time: 0.0348  loss: 1.4430  loss_disc_fake: 0.4062  loss_disc_real: 0.4380  loss_gen: 1.4430
# 04/22 06:13:33 - mmengine - INFO - Epoch(train) [220][120/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:02  time: 0.0722  data_time: 0.0359  loss: 1.4129  loss_disc_fake: 0.4066  loss_disc_real: 0.4719  loss_gen: 1.4129
# 04/22 06:13:34 - mmengine - INFO - Epoch(train) [220][130/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:01  time: 0.0689  data_time: 0.0340  loss: 1.4488  loss_disc_fake: 0.3969  loss_disc_real: 0.4367  loss_gen: 1.4488
# 04/22 06:13:34 - mmengine - INFO - Epoch(train) [220][140/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:01  time: 0.0685  data_time: 0.0334  loss: 1.5526  loss_disc_fake: 0.5041  loss_disc_real: 0.5591  loss_gen: 1.5526
# 04/22 06:13:35 - mmengine - INFO - Epoch(train) [220][150/157]  generator.lr: 1.0000e-04 discriminator.lr: 1.0000e-04  eta: 0:00:00  time: 0.0716  data_time: 0.0348  loss: 1.5016  loss_disc_fake: 0.4582  loss_disc_real: 0.5160  loss_gen: 1.5016
# 04/22 06:13:35 - mmengine - INFO - Exp name: 20250422_053147
# 04/22 06:13:35 - mmengine - INFO - Saving checkpoint at 220 epochs
# GAN(
#   (data_preprocessor): ImgDataPreprocessor()
#   (generator): Generator(
#     (model): Sequential(
#       (0): Linear(in_features=100, out_features=128, bias=True)
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#       (2): Linear(in_features=128, out_features=256, bias=True)
#       (3): BatchNorm1d(256, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#       (4): LeakyReLU(negative_slope=0.2, inplace=True)
#       (5): Linear(in_features=256, out_features=512, bias=True)
#       (6): BatchNorm1d(512, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#       (7): LeakyReLU(negative_slope=0.2, inplace=True)
#       (8): Linear(in_features=512, out_features=1024, bias=True)
#       (9): BatchNorm1d(1024, eps=0.8, momentum=0.1, affine=True, track_running_stats=True)
#       (10): LeakyReLU(negative_slope=0.2, inplace=True)
#       (11): Linear(in_features=1024, out_features=784, bias=True)
#       (12): Tanh()
#     )
#   )
#   (discriminator): Discriminator(
#     (model): Sequential(
#       (0): Linear(in_features=784, out_features=512, bias=True)
#       (1): LeakyReLU(negative_slope=0.2, inplace=True)
#       (2): Linear(in_features=512, out_features=256, bias=True)
#       (3): LeakyReLU(negative_slope=0.2, inplace=True)
#       (4): Linear(in_features=256, out_features=1, bias=True)
#       (5): Sigmoid()
#     )
#   )
# )

# %% [markdown]
# 到这里，我们就完成了一个 GAN 的训练，通过下面的代码可以查看刚才训练的 GAN 生成的结果。

# %%
z = torch.randn(64, 100)
img = model(z)

from torchvision.utils import save_image
save_image(img, "result.png", normalize=True)

# %% [markdown]
# 动态显示生成结果的图像数据: 使用 matplotlib 和 PIL 库。

# %%
from PIL import Image
import matplotlib.pyplot as plt

# 打开图片
img = Image.open('result.png') # 替换为你的图片路径

# 显示图片 (需要转换为 matplotlib 可识别的格式)
plt.imshow(img)
plt.axis('off') # 关闭坐标轴 (可选)
plt.show()
